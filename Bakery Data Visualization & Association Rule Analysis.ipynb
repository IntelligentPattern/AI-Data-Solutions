# %%
pip install apriori
# Out:
# Requirement already satisfied: apriori in c:\users\x1\anaconda3\lib\site-packages (1.0.0)Note: you may need to restart the kernel to use updated packages.

# %%
pip install apyori
# Out:
# Collecting apyori
#   Using cached apyori-1.1.2.tar.gz (8.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py): started
#   Building wheel for apyori (setup.py): finished with status 'done'
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5975 sha256=fd268a9d820b0c06f3cbabed4ce34c2fcf21703a2cf42fdc281f5afd9db0ba57
#   Stored in directory: c:\users\x1\appdata\local\pip\cache\wheels\77\3d\a6\d317a6fb32be58a602b1e8c6b5d6f31f79322da554cad2a5ea
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import apyori
from apyori import apriori

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("Bakery.csv")
df
# Out:
#        TransactionNo          Items             DateTime    Daypart  DayType
# 0                  1          Bread  2016-10-30 09:58:11    Morning  Weekend
# 1                  2   Scandinavian  2016-10-30 10:05:34    Morning  Weekend
# 2                  2   Scandinavian  2016-10-30 10:05:34    Morning  Weekend
# 3                  3  Hot chocolate  2016-10-30 10:07:57    Morning  Weekend
# 4                  3            Jam  2016-10-30 10:07:57    Morning  Weekend
# ...              ...            ...                  ...        ...      ...
# 20502           9682         Coffee  2017-09-04 14:32:58  Afternoon  Weekend
# 20503           9682            Tea  2017-09-04 14:32:58  Afternoon  Weekend
# 20504           9683         Coffee  2017-09-04 14:57:06  Afternoon  Weekend
# 20505           9683         Pastry  2017-09-04 14:57:06  Afternoon  Weekend
# 20506           9684      Smoothies  2017-09-04 15:04:24  Afternoon  Weekend
#
# [20507 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20507 entries, 0 to 20506
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TransactionNo  20507 non-null  int64
#  1   Items          20507 non-null  object
#  2   DateTime       20507 non-null  object
#  3   Daypart        20507 non-null  object
#  4   DayType        20507 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 801.2+ KB

# %%
len(df)
# Out:
# 20507

# %%
df["DateTime"] = pd.to_datetime(df["DateTime"])

df["day"] = df["DateTime"].apply(lambda x : x.day)
df["month"] = df["DateTime"].apply(lambda x : x.month)
df["year"] = df["DateTime"].apply(lambda x : x.year)

days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
df["weekday"] = df["DateTime"].apply(lambda x : days[x.weekday()])

# %%
df = df.drop("DateTime", axis=1)
df.head()
# Out:
#    TransactionNo          Items  Daypart  DayType  day  month  year weekday
# 0              1          Bread  Morning  Weekend   30     10  2016  Sunday
# 1              2   Scandinavian  Morning  Weekend   30     10  2016  Sunday
# 2              2   Scandinavian  Morning  Weekend   30     10  2016  Sunday
# 3              3  Hot chocolate  Morning  Weekend   30     10  2016  Sunday
# 4              3            Jam  Morning  Weekend   30     10  2016  Sunday

# %%
len(df["TransactionNo"].value_counts())
# Out:
# 9465

# %%
val_counts = dict(df["Items"].value_counts()[:10])

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=list(val_counts.keys()), y=list(val_counts.values()), palette="Greens_r")
# Out:
# <Axes: >

# %%
daypart = dict(df.groupby('Daypart')['Items'].count().sort_values(ascending=False))

# %%
plt.figure(figsize=(10,6))
plt.pie(daypart.values(), labels=daypart.keys(), explode=[0, 0.01, 0.2, 0.5], colors = sns.color_palette("Set2")[1:], autopct='%.2f%%')
plt.tight_layout()
plt.legend()
plt.show()

# %%
daytype = dict(df.groupby("DayType")["Items"].count().sort_values(ascending=False))

# %%
plt.figure(figsize=(10,6))
plt.pie(daytype.values(), labels=daytype.keys(), explode = [0, 0.01], colors = sns.color_palette("Set2")[5:7], autopct='%.2f%%')
plt.tight_layout()
plt.legend()
plt.show()

# %%
weekday = dict(df.groupby("weekday")["Items"].count().sort_values(ascending=False))

# %%
plt.figure(figsize=(10,6))
sns.barplot(y=list(weekday.keys()), x=list(weekday.values()), palette="Reds_r", orient = "h")
# Out:
# <Axes: >

# %%
year = dict(df.groupby("year")["Items"].count().sort_values(ascending=False))
plt.figure(figsize=(10,6))
plt.pie(year.values(), labels=year.keys(), explode = [0, 0.01], colors = sns.color_palette("hls",8)[5:3:-1], autopct='%.2f%%')
plt.tight_layout()
plt.legend()
plt.show()

# %%
month = dict(df.groupby("month")["Items"].count().sort_values(ascending=False))
plt.figure(figsize=(14,6))
sns.barplot(x=["March", "November", "January", "February", "December", "April", "October", "May", "July", "June", "August", "September"], 
            y=list(month.values()), palette="Purples_r")
# Out:
# <Axes: >

# %%
val_counts = df["Items"].value_counts()
val_counts.tail(10)
# Out:
# Chimichurri Oil    2
# Siblings           2
# Chicken sand       1
# The BART           1
# Adjustment         1
# Bacon              1
# Gift voucher       1
# Olum & polenta     1
# Raw bars           1
# Polenta            1
# Name: Items, dtype: int64

# %%
excluded = list(val_counts[val_counts.values < 2].index)

# %%
transactions=[]
for action in df["TransactionNo"].unique():
    transaction=list(set(df[df["TransactionNo"]==action]['Items']))
    if not any(x in transaction for x in excluded):
        if len(transaction) != 1:
            transactions.append(transaction)

# %%
len(transactions)
# Out:
# 5510

# %%
transactions[0:20]
# Out:
# [['Hot chocolate', 'Cookies', 'Jam'],
#  ['Bread', 'Coffee', 'Pastry'],
#  ['Medialuna', 'Muffin', 'Pastry'],
#  ['Medialuna', 'Coffee', 'Tea', 'Pastry'],
#  ['Bread', 'Pastry'],
#  ['Bread', 'Muffin'],
#  ['Medialuna', 'Scandinavian'],
#  ['Bread', 'Medialuna'],
#  ['Coffee', 'Jam', 'Tea', 'Tartine', 'Pastry'],
#  ['Basket', 'Bread', 'Coffee'],
#  ['Bread', 'Medialuna', 'Pastry'],
#  ['Scandinavian', 'Mineral water'],
#  ['Bread', 'Medialuna', 'Coffee'],
#  ['Bread', 'Farm House'],
#  ['Bread', 'Medialuna'],
#  ['Bread', 'Medialuna', 'Coffee'],
#  ['Scandinavian', 'Muffin'],
#  ['Bread', 'Coffee'],
#  ['Bread', 'Jam'],
#  ['Scandinavian', 'Muffin']]

# %%
#from mlxtend.frequent_patterns import association_rules
#from mlxtend.frequent_patterns import apriori
#frequent_itemsets = apriori(df, min_support = 0.00000001,max_len = 2, use_colnames = True)

# %%
rules = apriori(transactions,min_support=0.00030,min_confidance=0.7,min_lift=3,min_length=3,target="rules")
association_results = list(rules)

# %%
for item in association_results:

    pair = item[0] 
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    print("Support: " + str(item[1]))

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: Argentina Night -> Afternoon with the baker
# Support: 0.0003629764065335753
# Confidence: 0.16666666666666663
# Lift: 229.5833333333333
# =====================================
# Rule: Afternoon with the baker -> Spanish Brunch
# Support: 0.0003629764065335753
# Confidence: 0.16666666666666663
# Lift: 5.46626984126984
# =====================================
# Rule: Crepes -> Alfajores
# Support: 0.0003629764065335753
# Confidence: 0.006269592476489028
# Lift: 5.757575757575757
# =====================================
# Rule: Dulce de Leche -> Alfajores
# Support: 0.000544464609800363
# Confidence: 0.009404388714733543
# Lift: 5.757575757575758
# =====================================
# Rule: Frittata -> Art Tray
# Support: 0.0003629764065335753
# Confidence: 0.05405405405405405
# Lift: 3.918918918918919
# =====================================
# Rule: Hack the stack -> Art Tray
# Support: 0.0003629764065335753
# Confidence: 0.05405405405405405
# Lift: 148.9189189189189
# =====================================
# Rule: Art Tray -> Hearty & Seasonal
# Support: 0.0003629764065335753
# Confidence: 0.05405405405405405
# Lift: 3.2729432729432726
# =====================================
# Rule: Juice -> Art Tray
# Support: 0.0012704174228675136
# Confidence: 0.1891891891891892
# Lift: 3.0303268384663733
# =====================================
# Rule: Art Tray -> My-5 Fruit Shoot
# Support: 0.0003629764065335753
# Confidence: 0.05405405405405405
# Lift: 16.546546546546544
# =====================================
# Rule: Salad -> Art Tray
# Support: 0.000544464609800363
# Confidence: 0.08108108108108109
# Lift: 4.9094149094149095
# =====================================
# Rule: Soup -> Art Tray
# Support: 0.001088929219600726
# Confidence: 0.16216216216216217
# Lift: 3.1241731241731245
# =====================================
# Rule: Spanish Brunch -> Art Tray
# Support: 0.0007259528130671506
# Confidence: 0.1081081081081081
# Lift: 3.545688545688545
# =====================================
# Rule: Baguette -> Scandinavian
# Support: 0.001633393829401089
# Confidence: 0.10227272727272728
# Lift: 3.522017045454546
# =====================================
# Rule: Cookies -> Bare Popcorn
# Support: 0.0003629764065335753
# Confidence: 0.5
# Lift: 5.861702127659575
# =====================================
# Rule: Juice -> Bare Popcorn
# Support: 0.0003629764065335753
# Confidence: 0.5
# Lift: 8.008720930232558
# =====================================
# Rule: Hot chocolate -> Basket
# Support: 0.0003629764065335753
# Confidence: 0.39999999999999997
# Lift: 4.563146997929606
# =====================================
# Rule: Brownie -> My-5 Fruit Shoot
# Support: 0.0007259528130671506
# Confidence: 0.011594202898550725
# Lift: 3.549114331723027
# =====================================
# Rule: Coke -> Chicken Stew
# Support: 0.0018148820326678765
# Confidence: 0.09523809523809525
# Lift: 3.830378866875218
# =====================================
# Rule: Granola -> Chicken Stew
# Support: 0.0003629764065335753
# Confidence: 0.019047619047619046
# Lift: 4.0366300366300365
# =====================================
# Rule: Spanish Brunch -> Chicken Stew
# Support: 0.001996370235934664
# Confidence: 0.10476190476190476
# Lift: 3.4359410430839
# =====================================
# Rule: Coke -> Chocolates
# Support: 0.000544464609800363
# Confidence: 0.33333333333333337
# Lift: 13.406326034063262
# =====================================
# Rule: Hot chocolate -> Chocolates
# Support: 0.0007259528130671506
# Confidence: 0.4444444444444444
# Lift: 5.070163331032895
# =====================================
# Rule: Chocolates -> Juice
# Support: 0.0007259528130671506
# Confidence: 0.4444444444444444
# Lift: 7.118863049095607
# =====================================
# Rule: Christmas common -> Jam
# Support: 0.0003629764065335753
# Confidence: 0.39999999999999997
# Lift: 21.398058252427184
# =====================================
# Rule: Coke -> Crisps
# Support: 0.0003629764065335753
# Confidence: 0.014598540145985401
# Lift: 6.703163017031629
# =====================================
# Rule: Coke -> Mineral water
# Support: 0.001996370235934664
# Confidence: 0.08029197080291971
# Lift: 3.8138686131386863
# =====================================
# Rule: Salad -> Coke
# Support: 0.0012704174228675136
# Confidence: 0.051094890510948905
# Lift: 3.0937675463222907
# =====================================
# Rule: Coke -> Sandwich
# Support: 0.008892921960072596
# Confidence: 0.35766423357664234
# Lift: 3.2148938450363773
# =====================================
# Rule: Tacos/Fajita -> Coke
# Support: 0.0003629764065335753
# Confidence: 0.014598540145985401
# Lift: 7.312541473125415
# =====================================
# Rule: Vegan Feast -> Cookies
# Support: 0.0003629764065335753
# Confidence: 0.00425531914893617
# Lift: 3.907801418439716
# =====================================
# Rule: Medialuna -> Crepes
# Support: 0.0003629764065335753
# Confidence: 0.33333333333333326
# Lift: 3.4785353535353525
# =====================================
# Rule: Crisps -> Frittata
# Support: 0.0003629764065335753
# Confidence: 0.16666666666666663
# Lift: 12.08333333333333
# =====================================
# Rule: Crisps -> Juice
# Support: 0.001088929219600726
# Confidence: 0.5
# Lift: 8.008720930232558
# =====================================
# Rule: Mineral water -> Crisps
# Support: 0.0003629764065335753
# Confidence: 0.16666666666666663
# Lift: 7.916666666666665
# =====================================
# Rule: Sandwich -> Crisps
# Support: 0.001088929219600726
# Confidence: 0.5
# Lift: 4.494290375203915
# =====================================
# Rule: Crisps -> Truffles
# Support: 0.000544464609800363
# Confidence: 0.25
# Lift: 7.871428571428572
# =====================================
# Rule: Drinking chocolate spoons  -> Juice
# Support: 0.0003629764065335753
# Confidence: 0.25
# Lift: 4.004360465116279
# =====================================
# Rule: Drinking chocolate spoons  -> Mineral water
# Support: 0.0003629764065335753
# Confidence: 0.25
# Lift: 11.875
# =====================================
# Rule: Extra Salami or Feta -> Duck egg
# Support: 0.0003629764065335753
# Confidence: 0.16666666666666663
# Lift: 24.819819819819813
# =====================================
# Rule: Duck egg -> Spanish Brunch
# Support: 0.001088929219600726
# Confidence: 0.5
# Lift: 16.398809523809522
# =====================================
# Rule: Duck egg -> Truffles
# Support: 0.0003629764065335753
# Confidence: 0.16666666666666663
# Lift: 5.247619047619047
# =====================================
# Rule: Fudge -> Dulce de Leche
# Support: 0.0003629764065335753
# Confidence: 0.2222222222222222
# Lift: 13.309178743961354
# =====================================
# Rule: Fudge -> Eggs
# Support: 0.0003629764065335753
# Confidence: 0.09090909090909091
# Lift: 5.444664031620554
# =====================================
# Rule: Scandinavian -> Eggs
# Support: 0.0003629764065335753
# Confidence: 0.09090909090909091
# Lift: 3.1306818181818183
# =====================================
# Rule: Jam -> Ella's Kitchen Pouches
# Support: 0.0003629764065335753
# Confidence: 0.13333333333333333
# Lift: 7.132686084142395
# =====================================
# Rule: Ella's Kitchen Pouches -> Juice
# Support: 0.001088929219600726
# Confidence: 0.4
# Lift: 6.406976744186046
# =====================================
# Rule: Salad -> Extra Salami or Feta
# Support: 0.0029038112522686023
# Confidence: 0.4324324324324324
# Lift: 26.18354618354618
# =====================================
# Rule: Extra Salami or Feta -> Spanish Brunch
# Support: 0.0014519056261343012
# Confidence: 0.2162162162162162
# Lift: 7.09137709137709
# =====================================
# Rule: Farm House -> Focaccia
# Support: 0.0007259528130671506
# Confidence: 0.02352941176470588
# Lift: 3.0868347338935567
# =====================================
# Rule: Farm House -> Scandinavian
# Support: 0.0029038112522686023
# Confidence: 0.09411764705882351
# Lift: 3.241176470588235
# =====================================
# Rule: Fudge -> Focaccia
# Support: 0.0007259528130671506
# Confidence: 0.09523809523809523
# Lift: 5.703933747412009
# =====================================
# Rule: Focaccia -> Scandinavian
# Support: 0.0007259528130671506
# Confidence: 0.09523809523809523
# Lift: 3.2797619047619047
# =====================================
# Rule: Mineral water -> Frittata
# Support: 0.001088929219600726
# Confidence: 0.07894736842105264
# Lift: 3.7500000000000004
# =====================================
# Rule: Fudge -> Jam
# Support: 0.004355716878402904
# Confidence: 0.26086956521739135
# Lift: 13.955255382017732
# =====================================
# Rule: Half slice Monster  -> Juice
# Support: 0.0003629764065335753
# Confidence: 0.5
# Lift: 8.008720930232558
# =====================================
# Rule: Mighty Protein -> Hearty & Seasonal
# Support: 0.0003629764065335753
# Confidence: 0.021978021978021976
# Lift: 11.008991008991009
# =====================================
# Rule: Mineral water -> Hearty & Seasonal
# Support: 0.001633393829401089
# Confidence: 0.0989010989010989
# Lift: 4.697802197802198
# =====================================
# Rule: Pick and Mix Bowls -> Hearty & Seasonal
# Support: 0.000544464609800363
# Confidence: 0.03296703296703297
# Lift: 16.513486513486516
# =====================================
# Rule: Smoothies -> Hearty & Seasonal
# Support: 0.0009074410163339383
# Confidence: 0.054945054945054944
# Lift: 4.204822954822955
# =====================================
# Rule: Pick and Mix Bowls -> Jam
# Support: 0.0003629764065335753
# Confidence: 0.019417475728155338
# Lift: 9.72639011473963
# =====================================
# Rule: Tartine -> Jam
# Support: 0.0007259528130671506
# Confidence: 0.038834951456310676
# Lift: 5.094775774387424
# =====================================
# Rule: Jammie Dodgers -> Tiffin
# Support: 0.001996370235934664
# Confidence: 0.09322033898305085
# Lift: 3.8047708725674827
# =====================================
# Rule: Jammie Dodgers -> Vegan mincepie
# Support: 0.0009074410163339383
# Confidence: 0.0423728813559322
# Lift: 4.764787270840539
# =====================================
# Rule: Pick and Mix Bowls -> Juice
# Support: 0.0007259528130671506
# Confidence: 0.011627906976744184
# Lift: 5.824524312896405
# =====================================
# Rule: Tacos/Fajita -> Juice
# Support: 0.000544464609800363
# Confidence: 0.00872093023255814
# Lift: 4.368393234672305
# =====================================
# Rule: Kids biscuit -> Muffin
# Support: 0.000544464609800363
# Confidence: 0.30000000000000004
# Lift: 5.101851851851853
# =====================================
# Rule: Pick and Mix Bowls -> Mineral water
# Support: 0.000544464609800363
# Confidence: 0.025862068965517244
# Lift: 12.954545454545457
# =====================================
# Rule: Salad -> Mineral water
# Support: 0.001088929219600726
# Confidence: 0.05172413793103449
# Lift: 3.1318681318681323
# =====================================
# Rule: Pick and Mix Bowls -> Tartine
# Support: 0.000544464609800363
# Confidence: 0.27272727272727276
# Lift: 35.77922077922078
# =====================================
# Rule: Tshirt -> Postcard
# Support: 0.001088929219600726
# Confidence: 0.8571428571428572
# Lift: 429.3506493506494
# =====================================
# Rule: Tea -> Raspberry shortbread sandwich
# Support: 0.0003629764065335753
# Confidence: 0.6666666666666665
# Lift: 3.2109557109557105
# =====================================
# Rule: Salad -> Spanish Brunch
# Support: 0.002177858439201452
# Confidence: 0.13186813186813187
# Lift: 4.324960753532182
# =====================================
# Rule: Smoothies -> Spanish Brunch
# Support: 0.001633393829401089
# Confidence: 0.125
# Lift: 4.0997023809523805
# =====================================
# Rule: Spanish Brunch -> The Nomad
# Support: 0.001633393829401089
# Confidence: 0.05357142857142857
# Lift: 5.466269841269841
# =====================================
# Rule: Spanish Brunch -> Truffles
# Support: 0.0030852994555353903
# Confidence: 0.10119047619047619
# Lift: 3.1860544217687075
# =====================================
# Rule: Tacos/Fajita -> Truffles
# Support: 0.0003629764065335753
# Confidence: 0.18181818181818182
# Lift: 5.724675324675325
# =====================================
# Rule: Victorian Sponge -> Tea
# Support: 0.0007259528130671506
# Confidence: 0.0034965034965034965
# Lift: 3.2109557109557105
# =====================================
# Rule: Tshirt -> Valentine's card
# Support: 0.0003629764065335753
# Confidence: 0.18181818181818182
# Lift: 333.93939393939394
# =====================================
# Rule: Argentina Night -> Afternoon with the baker
# Support: 0.0003629764065335753
# Confidence: 0.16666666666666663
# Lift: 459.1666666666666
# =====================================
# Rule: Bread -> Afternoon with the baker
# Support: 0.0003629764065335753
# Confidence: 0.16666666666666663
# Lift: 13.119047619047615
# =====================================
# Rule: Bakewell -> Bread
# Support: 0.0003629764065335753
# Confidence: 0.006269592476489028
# Lift: 3.1404958677685952
# =====================================
# Rule: Bakewell -> Tea
# Support: 0.0003629764065335753
# Confidence: 0.043478260869565216
# Lift: 3.7432065217391304
# =====================================
# Rule: Brownie -> Juice
# Support: 0.001088929219600726
# Confidence: 0.018808777429467086
# Lift: 4.318181818181818
# =====================================
# Rule: Chicken Stew -> Cake
# Support: 0.0003629764065335753
# Confidence: 0.002262443438914027
# Lift: 4.155354449472096
# =====================================
# Rule: Mineral water -> Cake
# Support: 0.000544464609800363
# Confidence: 0.009404388714733543
# Lift: 3.9860139860139863
# =====================================
# Rule: Tea -> Chicken Stew
# Support: 0.0003629764065335753
# Confidence: 0.0017482517482517483
# Lift: 3.2109557109557105
# =====================================
# Rule: Coke -> Juice
# Support: 0.0003629764065335753
# Confidence: 0.005813953488372092
# Lift: 5.339147286821704
# =====================================
# Rule: Coke -> Pastry
# Support: 0.0003629764065335753
# Confidence: 0.006269592476489028
# Lift: 4.318181818181818
# =====================================
# Rule: Coke -> Sandwich
# Support: 0.0003629764065335753
# Confidence: 0.014598540145985401
# Lift: 3.2175182481751823
# =====================================
# Rule: Juice -> Cookies
# Support: 0.0018148820326678765
# Confidence: 0.02127659574468085
# Lift: 4.042553191489362
# =====================================
# Rule: Mineral water -> Cookies
# Support: 0.0007259528130671506
# Confidence: 0.012539184952978056
# Lift: 5.314685314685314
# =====================================
# Rule: Scandinavian -> Farm House
# Support: 0.0003629764065335753
# Confidence: 0.01176470588235294
# Lift: 4.630252100840336
# =====================================
# Rule: Fudge -> Medialuna
# Support: 0.0003629764065335753
# Confidence: 0.006269592476489028
# Lift: 4.9350649350649345
# =====================================
# Rule: Fudge -> Sandwich
# Support: 0.0003629764065335753
# Confidence: 0.021739130434782608
# Lift: 4.791304347826086
# =====================================
# Rule: Hot chocolate -> Mineral water
# Support: 0.0003629764065335753
# Confidence: 0.006269592476489028
# Lift: 3.8383838383838382
# =====================================
# Rule: Hot chocolate -> Spanish Brunch
# Support: 0.0003629764065335753
# Confidence: 0.006269592476489028
# Lift: 4.318181818181818
# =====================================
# Rule: Hot chocolate -> Toast
# Support: 0.0003629764065335753
# Confidence: 0.004140786749482401
# Lift: 4.563146997929606
# =====================================
# Rule: Medialuna -> Jam
# Support: 0.0003629764065335753
# Confidence: 0.006269592476489028
# Lift: 6.909090909090909
# =====================================
# Rule: Tea -> Jam
# Support: 0.0003629764065335753
# Confidence: 0.0017482517482517483
# Lift: 4.816433566433567
# =====================================
# Rule: Mineral water -> Juice
# Support: 0.0003629764065335753
# Confidence: 0.017241379310344827
# Lift: 3.2758620689655173
# =====================================
# Rule: Sandwich -> Juice
# Support: 0.0009074410163339383
# Confidence: 0.01453488372093023
# Lift: 3.2034883720930227
# =====================================
# Rule: Spanish Brunch -> Juice
# Support: 0.000544464609800363
# Confidence: 0.00872093023255814
# Lift: 4.805232558139535
# =====================================
# Rule: Toast -> Juice
# Support: 0.0003629764065335753
# Confidence: 0.005813953488372092
# Lift: 6.4069767441860455
# =====================================
# Rule: Truffles -> Juice
# Support: 0.000544464609800363
# Confidence: 0.00872093023255814
# Lift: 4.368393234672305
# =====================================
# Rule: Sandwich -> Mineral water
# Support: 0.000544464609800363
# Confidence: 0.025862068965517244
# Lift: 5.7
# =====================================
# Rule: Tea -> Mineral water
# Support: 0.000544464609800363
# Confidence: 0.009404388714733543
# Lift: 4.318181818181818
# =====================================
# Rule: Tiffin -> Muffin
# Support: 0.0003629764065335753
# Confidence: 0.006269592476489028
# Lift: 5.757575757575757
# =====================================
# Rule: Tiffin -> Pastry
# Support: 0.0003629764065335753
# Confidence: 0.006269592476489028
# Lift: 4.9350649350649345
# =====================================
# Rule: Salad -> Sandwich
# Support: 0.0003629764065335753
# Confidence: 0.021978021978021976
# Lift: 4.843956043956044
# =====================================
# Rule: Scone -> Spanish Brunch
# Support: 0.0003629764065335753
# Confidence: 0.006269592476489028
# Lift: 5.757575757575757
# =====================================
# Rule: Spanish Brunch -> Tea
# Support: 0.0012704174228675136
# Confidence: 0.041666666666666664
# Lift: 3.5872395833333335
# =====================================
# Rule: Sandwich -> Brownie
# Support: 0.0003629764065335753
# Confidence: 0.05405405405405405
# Lift: 13.538083538083539
# =====================================
# Rule: Juice -> Cake
# Support: 0.0003629764065335753
# Confidence: 0.05405405405405405
# Lift: 4.44534086325131
# =====================================
# Rule: Chicken Stew -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.05405405405405405
# Lift: 6.078323221180363
# =====================================
# Rule: Coffee -> Art Tray
# Support: 0.0003629764065335753
# Confidence: 0.05405405405405405
# Lift: 5.515515515515515
# =====================================
# Rule: Salad -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.05405405405405405
# Lift: 4.803836094158675
# =====================================
# Rule: Soup -> Coffee
# Support: 0.0007259528130671506
# Confidence: 0.1081081081081081
# Lift: 3.971171171171171
# =====================================
# Rule: Spanish Brunch -> Coffee
# Support: 0.000544464609800363
# Confidence: 0.08108108108108109
# Lift: 4.337444240356862
# =====================================
# Rule: Truffles -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.05405405405405405
# Lift: 4.1948991244765885
# =====================================
# Rule: Juice -> Cookies
# Support: 0.0003629764065335753
# Confidence: 0.05405405405405405
# Lift: 5.135135135135135
# =====================================
# Rule: Hot chocolate -> Juice
# Support: 0.000544464609800363
# Confidence: 0.08108108108108109
# Lift: 21.274131274131275
# =====================================
# Rule: Hot chocolate -> Sandwich
# Support: 0.0003629764065335753
# Confidence: 0.05405405405405405
# Lift: 7.09137709137709
# =====================================
# Rule: Hot chocolate -> Tea
# Support: 0.000544464609800363
# Confidence: 0.08108108108108109
# Lift: 5.878378378378379
# =====================================
# Rule: Muffin -> Juice
# Support: 0.0003629764065335753
# Confidence: 0.05405405405405405
# Lift: 11.455301455301454
# =====================================
# Rule: Spanish Brunch -> Juice
# Support: 0.0003629764065335753
# Confidence: 0.05405405405405405
# Lift: 11.455301455301454
# =====================================
# Rule: Toast -> Juice
# Support: 0.0003629764065335753
# Confidence: 0.05405405405405405
# Lift: 13.538083538083539
# =====================================
# Rule: Baguette -> Cake
# Support: 0.0003629764065335753
# Confidence: 0.022727272727272728
# Lift: 8.944805194805195
# =====================================
# Rule: Bakewell -> Bread
# Support: 0.0003629764065335753
# Confidence: 0.043478260869565216
# Lift: 3.2373678025851937
# =====================================
# Rule: Bakewell -> Cake
# Support: 0.0003629764065335753
# Confidence: 0.043478260869565216
# Lift: 3.471959672337744
# =====================================
# Rule: Bakewell -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.043478260869565216
# Lift: 3.802622498274672
# =====================================
# Rule: Bakewell -> Sandwich
# Support: 0.0003629764065335753
# Confidence: 0.043478260869565216
# Lift: 8.872785829307569
# =====================================
# Rule: Bakewell -> Sandwich
# Support: 0.0003629764065335753
# Confidence: 0.043478260869565216
# Lift: 4.355731225296442
# =====================================
# Rule: Bakewell -> Tea
# Support: 0.0003629764065335753
# Confidence: 0.043478260869565216
# Lift: 3.523017902813299
# =====================================
# Rule: Cookies -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.5
# Lift: 10.318352059925093
# =====================================
# Rule: Juice -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.5
# Lift: 14.201030927835053
# =====================================
# Rule: Hot chocolate -> Basket
# Support: 0.0003629764065335753
# Confidence: 0.39999999999999997
# Lift: 7.87142857142857
# =====================================
# Rule: Bread -> Cake
# Support: 0.000544464609800363
# Confidence: 0.13636363636363638
# Lift: 3.3998354586589885
# =====================================
# Rule: Jammie Dodgers -> Bread
# Support: 0.0027223230490018148
# Confidence: 0.1271186440677966
# Lift: 3.1693381394278703
# =====================================
# Rule: Bread -> Lemon and coconut
# Support: 0.0003629764065335753
# Confidence: 0.002262443438914027
# Lift: 4.155354449472096
# =====================================
# Rule: Bread -> Coke
# Support: 0.0003629764065335753
# Confidence: 0.019047619047619046
# Lift: 5.83068783068783
# =====================================
# Rule: Bread -> Soup
# Support: 0.0012704174228675136
# Confidence: 0.06666666666666667
# Lift: 5.924731182795699
# =====================================
# Rule: Tiffin -> Bread
# Support: 0.000544464609800363
# Confidence: 0.028571428571428574
# Lift: 3.4223602484472058
# =====================================
# Rule: Hot chocolate -> Bread
# Support: 0.0003629764065335753
# Confidence: 0.2222222222222222
# Lift: 9.641294838145232
# =====================================
# Rule: Christmas common -> Bread
# Support: 0.0003629764065335753
# Confidence: 0.39999999999999997
# Lift: 45.91666666666666
# =====================================
# Rule: Bread -> Coke
# Support: 0.0003629764065335753
# Confidence: 0.01176470588235294
# Lift: 3.601307189542483
# =====================================
# Rule: Bread -> Coke
# Support: 0.000544464609800363
# Confidence: 0.021897810218978103
# Lift: 4.021897810218978
# =====================================
# Rule: Bread -> Coke
# Support: 0.0014519056261343012
# Confidence: 0.013050570962479607
# Lift: 3.994924777959035
# =====================================
# Rule: Bread -> Coke
# Support: 0.0007259528130671506
# Confidence: 0.013986013986013986
# Lift: 4.281274281274281
# =====================================
# Rule: Bread -> Coke
# Support: 0.0003629764065335753
# Confidence: 0.011428571428571429
# Lift: 3.4984126984126984
# =====================================
# Rule: Bread -> Crisps
# Support: 0.000544464609800363
# Confidence: 0.25
# Lift: 19.678571428571427
# =====================================
# Rule: Bread -> Crisps
# Support: 0.0003629764065335753
# Confidence: 0.16666666666666663
# Lift: 19.539007092198574
# =====================================
# Rule: Bread -> Duck egg
# Support: 0.0003629764065335753
# Confidence: 0.16666666666666663
# Lift: 3.4523809523809517
# =====================================
# Rule: Bread -> Juice
# Support: 0.0003629764065335753
# Confidence: 0.09090909090909091
# Lift: 7.1558441558441555
# =====================================
# Rule: Bread -> Medialuna
# Support: 0.0003629764065335753
# Confidence: 0.09090909090909091
# Lift: 3.1306818181818183
# =====================================
# Rule: Bread -> Ella's Kitchen Pouches
# Support: 0.0003629764065335753
# Confidence: 0.13333333333333333
# Lift: 9.541125541125542
# =====================================
# Rule: Salad -> Bread
# Support: 0.001088929219600726
# Confidence: 0.16216216216216217
# Lift: 47.02702702702703
# =====================================
# Rule: Bread -> Extra Salami or Feta
# Support: 0.0003629764065335753
# Confidence: 0.05405405405405405
# Lift: 4.803836094158675
# =====================================
# Rule: Bread -> Farm House
# Support: 0.0007259528130671506
# Confidence: 0.038834951456310676
# Lift: 4.552778351580251
# =====================================
# Rule: Bread -> Mineral water
# Support: 0.0003629764065335753
# Confidence: 0.02631578947368421
# Lift: 4.833333333333333
# =====================================
# Rule: Salad -> Bread
# Support: 0.0003629764065335753
# Confidence: 0.02631578947368421
# Lift: 7.63157894736842
# =====================================
# Rule: Bread -> Jam
# Support: 0.0007259528130671506
# Confidence: 0.043478260869565216
# Lift: 4.990942028985507
# =====================================
# Rule: Bread -> Mineral water
# Support: 0.000544464609800363
# Confidence: 0.03296703296703297
# Lift: 6.054945054945056
# =====================================
# Rule: Salad -> Bread
# Support: 0.0003629764065335753
# Confidence: 0.019417475728155338
# Lift: 5.631067961165048
# =====================================
# Rule: Jammie Dodgers -> Bread
# Support: 0.001088929219600726
# Confidence: 0.05084745762711865
# Lift: 4.0024213075060535
# =====================================
# Rule: Jammie Dodgers -> Bread
# Support: 0.0007259528130671506
# Confidence: 0.03389830508474576
# Lift: 4.060427413411938
# =====================================
# Rule: Salad -> Bread
# Support: 0.0003629764065335753
# Confidence: 0.017241379310344827
# Lift: 5.0
# =====================================
# Rule: Bread -> Spanish Brunch
# Support: 0.000544464609800363
# Confidence: 0.025862068965517244
# Lift: 3.1666666666666674
# =====================================
# Rule: Bread -> Mineral water
# Support: 0.000544464609800363
# Confidence: 0.025862068965517244
# Lift: 3.0319148936170213
# =====================================
# Rule: Bread -> Muffin
# Support: 0.0003629764065335753
# Confidence: 0.006172839506172839
# Lift: 6.802469135802469
# =====================================
# Rule: Salad -> Bread
# Support: 0.0003629764065335753
# Confidence: 0.012499999999999999
# Lift: 3.6249999999999996
# =====================================
# Rule: Salad -> Bread
# Support: 0.000544464609800363
# Confidence: 0.010489510489510492
# Lift: 3.0419580419580425
# =====================================
# Rule: Salad -> Bread
# Support: 0.000544464609800363
# Confidence: 0.03296703296703297
# Lift: 4.036630036630037
# =====================================
# Rule: Salad -> Bread
# Support: 0.0003629764065335753
# Confidence: 0.011428571428571429
# Lift: 3.3142857142857145
# =====================================
# Rule: Bread -> Smoothies
# Support: 0.0003629764065335753
# Confidence: 0.027777777777777776
# Lift: 3.4012345679012346
# =====================================
# Rule: Tacos/Fajita -> Bread
# Support: 0.0003629764065335753
# Confidence: 0.18181818181818182
# Lift: 21.315280464216634
# =====================================
# Rule: Tiffin -> Bread
# Support: 0.0003629764065335753
# Confidence: 0.037037037037037035
# Lift: 4.436392914653784
# =====================================
# Rule: Brownie -> Medialuna
# Support: 0.0003629764065335753
# Confidence: 0.005797101449275362
# Lift: 6.388405797101449
# =====================================
# Rule: Brownie -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.005797101449275362
# Lift: 4.563146997929607
# =====================================
# Rule: Mineral water -> Coke
# Support: 0.0003629764065335753
# Confidence: 0.014598540145985401
# Lift: 8.937550689375506
# =====================================
# Rule: Scone -> Coke
# Support: 0.0003629764065335753
# Confidence: 0.005797101449275362
# Lift: 6.388405797101449
# =====================================
# Rule: Coke -> Brownie
# Support: 0.0003629764065335753
# Confidence: 0.014598540145985401
# Lift: 7.312541473125415
# =====================================
# Rule: Brownie -> Farm House
# Support: 0.0003629764065335753
# Confidence: 0.005797101449275362
# Lift: 6.388405797101449
# =====================================
# Rule: Hot chocolate -> Brownie
# Support: 0.0003629764065335753
# Confidence: 0.005797101449275362
# Lift: 4.563146997929607
# =====================================
# Rule: Sandwich -> Brownie
# Support: 0.0003629764065335753
# Confidence: 0.021978021978021976
# Lift: 5.504495504495504
# =====================================
# Rule: Scone -> Brownie
# Support: 0.000544464609800363
# Confidence: 0.00872093023255814
# Lift: 4.004360465116279
# =====================================
# Rule: Brownie -> Truffles
# Support: 0.0003629764065335753
# Confidence: 0.011428571428571429
# Lift: 3.3142857142857145
# =====================================
# Rule: Spanish Brunch -> Brownie
# Support: 0.0003629764065335753
# Confidence: 0.011904761904761904
# Lift: 5.963203463203463
# =====================================
# Rule: Tea -> Brownie
# Support: 0.0009074410163339383
# Confidence: 0.004370629370629371
# Lift: 3.4403096903096904
# =====================================
# Rule: Juice -> Cake
# Support: 0.000544464609800363
# Confidence: 0.00872093023255814
# Lift: 3.0032703488372094
# =====================================
# Rule: Salad -> Cake
# Support: 0.0003629764065335753
# Confidence: 0.002262443438914027
# Lift: 3.1165158371040724
# =====================================
# Rule: Sandwich -> Cake
# Support: 0.0007259528130671506
# Confidence: 0.03809523809523809
# Lift: 3.229304029304029
# =====================================
# Rule: Soup -> Cake
# Support: 0.0007259528130671506
# Confidence: 0.03809523809523809
# Lift: 4.9977324263038545
# =====================================
# Rule: Spanish Brunch -> Cake
# Support: 0.0003629764065335753
# Confidence: 0.019047619047619046
# Lift: 4.770562770562771
# =====================================
# Rule: Truffles -> Cake
# Support: 0.000544464609800363
# Confidence: 0.028571428571428574
# Lift: 6.297142857142857
# =====================================
# Rule: Dulce de Leche -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.002262443438914027
# Lift: 4.155354449472096
# =====================================
# Rule: Duck egg -> Cake
# Support: 0.0003629764065335753
# Confidence: 0.16666666666666663
# Lift: 41.742424242424235
# =====================================
# Rule: Juice -> Cake
# Support: 0.0003629764065335753
# Confidence: 0.002262443438914027
# Lift: 4.155354449472096
# =====================================
# Rule: Hot chocolate -> Extra Salami or Feta
# Support: 0.0003629764065335753
# Confidence: 0.002262443438914027
# Lift: 6.233031674208145
# =====================================
# Rule: Salad -> Extra Salami or Feta
# Support: 0.000544464609800363
# Confidence: 0.08108108108108109
# Lift: 34.36590436590436
# =====================================
# Rule: Extra Salami or Feta -> Toast
# Support: 0.0003629764065335753
# Confidence: 0.05405405405405405
# Lift: 14.18275418275418
# =====================================
# Rule: Farm House -> Cake
# Support: 0.0003629764065335753
# Confidence: 0.01176470588235294
# Lift: 4.630252100840336
# =====================================
# Rule: Sandwich -> Granola
# Support: 0.0003629764065335753
# Confidence: 0.002262443438914027
# Lift: 4.155354449472096
# =====================================
# Rule: Hot chocolate -> Salad
# Support: 0.0003629764065335753
# Confidence: 0.002262443438914027
# Lift: 6.233031674208145
# =====================================
# Rule: Jammie Dodgers -> Cake
# Support: 0.0009074410163339383
# Confidence: 0.0423728813559322
# Lift: 3.484695168226663
# =====================================
# Rule: Jammie Dodgers -> Spanish Brunch
# Support: 0.0003629764065335753
# Confidence: 0.002262443438914027
# Lift: 6.233031674208145
# =====================================
# Rule: Jammie Dodgers -> Tiffin
# Support: 0.000544464609800363
# Confidence: 0.025423728813559324
# Lift: 6.3674884437596315
# =====================================
# Rule: Jammie Dodgers -> Truffles
# Support: 0.000544464609800363
# Confidence: 0.0033936651583710412
# Lift: 4.674773755656109
# =====================================
# Rule: Jammie Dodgers -> Vegan mincepie
# Support: 0.0003629764065335753
# Confidence: 0.01694915254237288
# Lift: 7.782485875706214
# =====================================
# Rule: Spanish Brunch -> Medialuna
# Support: 0.0007259528130671506
# Confidence: 0.004524886877828054
# Lift: 3.561732385261797
# =====================================
# Rule: Pastry -> Cake
# Support: 0.0003629764065335753
# Confidence: 0.002262443438914027
# Lift: 3.1165158371040724
# =====================================
# Rule: Salad -> Spanish Brunch
# Support: 0.0003629764065335753
# Confidence: 0.021978021978021976
# Lift: 5.504495504495504
# =====================================
# Rule: Salad -> Truffles
# Support: 0.0003629764065335753
# Confidence: 0.021978021978021976
# Lift: 4.843956043956044
# =====================================
# Rule: Sandwich -> Cake
# Support: 0.0007259528130671506
# Confidence: 0.05555555555555555
# Lift: 4.709401709401709
# =====================================
# Rule: Sandwich -> Cake
# Support: 0.001996370235934664
# Confidence: 0.038461538461538464
# Lift: 3.260355029585799
# =====================================
# Rule: Scone -> Cake
# Support: 0.0003629764065335753
# Confidence: 0.002262443438914027
# Lift: 3.1165158371040724
# =====================================
# Rule: Smoothies -> Cake
# Support: 0.0003629764065335753
# Confidence: 0.027777777777777776
# Lift: 3.644179894179894
# =====================================
# Rule: Smoothies -> Cake
# Support: 0.0003629764065335753
# Confidence: 0.027777777777777776
# Lift: 6.957070707070708
# =====================================
# Rule: Spanish Brunch -> The Nomad
# Support: 0.000544464609800363
# Confidence: 0.017857142857142856
# Lift: 14.056122448979592
# =====================================
# Rule: Spanish Brunch -> Toast
# Support: 0.0003629764065335753
# Confidence: 0.011904761904761904
# Lift: 3.123582766439909
# =====================================
# Rule: Spanish Brunch -> Cake
# Support: 0.000544464609800363
# Confidence: 0.017857142857142856
# Lift: 3.935714285714285
# =====================================
# Rule: Coke -> Coffee
# Support: 0.001088929219600726
# Confidence: 0.05714285714285715
# Lift: 5.161592505854801
# =====================================
# Rule: Extra Salami or Feta -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.019047619047619046
# Lift: 3.3855606758832564
# =====================================
# Rule: Salad -> Coffee
# Support: 0.000544464609800363
# Confidence: 0.03296703296703297
# Lift: 3.707109217313299
# =====================================
# Rule: The Nomad -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.019047619047619046
# Lift: 3.3855606758832564
# =====================================
# Rule: Truffles -> Coffee
# Support: 0.0009074410163339383
# Confidence: 0.04761904761904762
# Lift: 3.69550637156271
# =====================================
# Rule: Coke -> Juice
# Support: 0.0007259528130671506
# Confidence: 0.03809523809523809
# Lift: 9.995464852607709
# =====================================
# Rule: Coke -> Sandwich
# Support: 0.0007259528130671506
# Confidence: 0.03809523809523809
# Lift: 4.283770651117589
# =====================================
# Rule: Tiffin -> Coke
# Support: 0.0003629764065335753
# Confidence: 0.019047619047619046
# Lift: 26.238095238095237
# =====================================
# Rule: Coke -> Truffles
# Support: 0.000544464609800363
# Confidence: 0.028571428571428574
# Lift: 13.119047619047619
# =====================================
# Rule: Hot chocolate -> Toast
# Support: 0.0003629764065335753
# Confidence: 0.019047619047619046
# Lift: 3.6190476190476186
# =====================================
# Rule: Jammie Dodgers -> Tea
# Support: 0.0003629764065335753
# Confidence: 0.019047619047619046
# Lift: 4.373015873015873
# =====================================
# Rule: Sandwich -> Juice
# Support: 0.0007259528130671506
# Confidence: 0.03809523809523809
# Lift: 3.816450216450216
# =====================================
# Rule: Spanish Brunch -> Juice
# Support: 0.000544464609800363
# Confidence: 0.028571428571428574
# Lift: 6.054945054945056
# =====================================
# Rule: Truffles -> Juice
# Support: 0.0003629764065335753
# Confidence: 0.019047619047619046
# Lift: 5.523809523809524
# =====================================
# Rule: Sandwich -> Medialuna
# Support: 0.0003629764065335753
# Confidence: 0.019047619047619046
# Lift: 5.247619047619048
# =====================================
# Rule: Spanish Brunch -> Medialuna
# Support: 0.0003629764065335753
# Confidence: 0.019047619047619046
# Lift: 14.993197278911563
# =====================================
# Rule: Pastry -> Soup
# Support: 0.0003629764065335753
# Confidence: 0.019047619047619046
# Lift: 11.66137566137566
# =====================================
# Rule: Salad -> Truffles
# Support: 0.000544464609800363
# Confidence: 0.028571428571428574
# Lift: 22.48979591836735
# =====================================
# Rule: Sandwich -> Spanish Brunch
# Support: 0.0003629764065335753
# Confidence: 0.019047619047619046
# Lift: 5.83068783068783
# =====================================
# Rule: Sandwich -> Truffles
# Support: 0.000544464609800363
# Confidence: 0.028571428571428574
# Lift: 4.3730158730158735
# =====================================
# Rule: Soup -> Tea
# Support: 0.0012704174228675136
# Confidence: 0.06666666666666667
# Lift: 4.271317829457364
# =====================================
# Rule: Spanish Brunch -> Tea
# Support: 0.0007259528130671506
# Confidence: 0.03809523809523809
# Lift: 4.770562770562771
# =====================================
# Rule: Tiffin -> Tea
# Support: 0.0003629764065335753
# Confidence: 0.019047619047619046
# Lift: 3.18037518037518
# =====================================
# Rule: Coke -> Chocolates
# Support: 0.0003629764065335753
# Confidence: 0.2222222222222222
# Lift: 20.072859744990893
# =====================================
# Rule: Cookies -> Chocolates
# Support: 0.0003629764065335753
# Confidence: 0.2222222222222222
# Lift: 4.585934248855597
# =====================================
# Rule: Hot chocolate -> Chocolates
# Support: 0.0003629764065335753
# Confidence: 0.2222222222222222
# Lift: 4.373015873015873
# =====================================
# Rule: Chocolates -> Coffee
# Support: 0.000544464609800363
# Confidence: 0.33333333333333337
# Lift: 9.467353951890036
# =====================================
# Rule: Coke -> Chocolates
# Support: 0.0003629764065335753
# Confidence: 0.2222222222222222
# Lift: 58.3068783068783
# =====================================
# Rule: Tea -> Coke
# Support: 0.0003629764065335753
# Confidence: 0.2222222222222222
# Lift: 58.3068783068783
# =====================================
# Rule: Chocolates -> Cookies
# Support: 0.0003629764065335753
# Confidence: 0.2222222222222222
# Lift: 21.11111111111111
# =====================================
# Rule: Hot chocolate -> Chocolates
# Support: 0.000544464609800363
# Confidence: 0.33333333333333337
# Lift: 87.46031746031747
# =====================================
# Rule: Tea -> Chocolates
# Support: 0.0003629764065335753
# Confidence: 0.2222222222222222
# Lift: 18.006535947712415
# =====================================
# Rule: Coke -> Mineral water
# Support: 0.0009074410163339383
# Confidence: 0.0364963503649635
# Lift: 3.7942432171877147
# =====================================
# Rule: Coke -> Coffee
# Support: 0.001088929219600726
# Confidence: 0.043795620437956206
# Lift: 3.3987868818751927
# =====================================
# Rule: Cookies -> Crisps
# Support: 0.0003629764065335753
# Confidence: 0.16666666666666663
# Lift: 3.439450686641697
# =====================================
# Rule: Cookies -> Duck egg
# Support: 0.0003629764065335753
# Confidence: 0.00425531914893617
# Lift: 3.349544072948328
# =====================================
# Rule: Cookies -> Coffee
# Support: 0.000544464609800363
# Confidence: 0.006382978723404256
# Lift: 5.024316109422493
# =====================================
# Rule: Crisps -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.16666666666666663
# Lift: 21.86507936507936
# =====================================
# Rule: Hot chocolate -> Crisps
# Support: 0.000544464609800363
# Confidence: 0.25
# Lift: 4.919642857142857
# =====================================
# Rule: Crisps -> Coffee
# Support: 0.0009074410163339383
# Confidence: 0.41666666666666663
# Lift: 11.834192439862543
# =====================================
# Rule: Sandwich -> Crisps
# Support: 0.000544464609800363
# Confidence: 0.25
# Lift: 3.80524861878453
# =====================================
# Rule: Truffles -> Crisps
# Support: 0.0003629764065335753
# Confidence: 0.16666666666666663
# Lift: 12.93427230046948
# =====================================
# Rule: Drinking chocolate spoons  -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.25
# Lift: 7.100515463917526
# =====================================
# Rule: Drinking chocolate spoons  -> Mineral water
# Support: 0.0003629764065335753
# Confidence: 0.25
# Lift: 25.99056603773585
# =====================================
# Rule: Drinking chocolate spoons  -> Sandwich
# Support: 0.0003629764065335753
# Confidence: 0.25
# Lift: 3.80524861878453
# =====================================
# Rule: Duck egg -> Coffee
# Support: 0.000544464609800363
# Confidence: 0.25
# Lift: 13.37378640776699
# =====================================
# Rule: Ella's Kitchen Pouches -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.13333333333333333
# Lift: 3.7869415807560136
# =====================================
# Rule: Ella's Kitchen Pouches -> Medialuna
# Support: 0.0003629764065335753
# Confidence: 0.0037878787878787876
# Lift: 3.478535353535353
# =====================================
# Rule: Extra Salami or Feta -> Coffee
# Support: 0.0007259528130671506
# Confidence: 0.1081081081081081
# Lift: 3.070493173585957
# =====================================
# Rule: Salad -> Extra Salami or Feta
# Support: 0.002540834845735027
# Confidence: 0.3783783783783784
# Lift: 33.626852659110725
# =====================================
# Rule: Extra Salami or Feta -> Spanish Brunch
# Support: 0.001088929219600726
# Confidence: 0.16216216216216217
# Lift: 8.674888480713724
# =====================================
# Rule: Extra Salami or Feta -> Toast
# Support: 0.001088929219600726
# Confidence: 0.16216216216216217
# Lift: 3.9888996138996142
# =====================================
# Rule: Focaccia -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.047619047619047616
# Lift: 4.858906525573192
# =====================================
# Rule: Focaccia -> Coffee
# Support: 0.000544464609800363
# Confidence: 0.005681818181818182
# Lift: 3.4785353535353534
# =====================================
# Rule: Mineral water -> Coffee
# Support: 0.000544464609800363
# Confidence: 0.03947368421052632
# Lift: 4.103773584905661
# =====================================
# Rule: Smoothies -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.02631578947368421
# Lift: 3.81578947368421
# =====================================
# Rule: Fudge -> Jam
# Support: 0.001088929219600726
# Confidence: 0.06521739130434784
# Lift: 9.214046822742477
# =====================================
# Rule: Granola -> Toast
# Support: 0.000544464609800363
# Confidence: 0.00986842105263158
# Lift: 3.198529411764706
# =====================================
# Rule: Half slice Monster  -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.5
# Lift: 14.201030927835053
# =====================================
# Rule: Mighty Protein -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.021978021978021976
# Lift: 13.455433455433454
# =====================================
# Rule: Mineral water -> Coffee
# Support: 0.000544464609800363
# Confidence: 0.03296703296703297
# Lift: 3.4273273895915404
# =====================================
# Rule: Pick and Mix Bowls -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.021978021978021976
# Lift: 20.18315018315018
# =====================================
# Rule: Smoothies -> Coffee
# Support: 0.000544464609800363
# Confidence: 0.03296703296703297
# Lift: 4.78021978021978
# =====================================
# Rule: Tea -> Honey
# Support: 0.0003629764065335753
# Confidence: 0.39999999999999997
# Lift: 4.679405520169851
# =====================================
# Rule: Keeping It Local -> Jam
# Support: 0.0003629764065335753
# Confidence: 0.031746031746031744
# Lift: 4.485144485144485
# =====================================
# Rule: Tartine -> Jam
# Support: 0.000544464609800363
# Confidence: 0.029126213592233014
# Lift: 5.533980582524273
# =====================================
# Rule: Jammie Dodgers -> Coffee
# Support: 0.0023593466424682396
# Confidence: 0.11016949152542374
# Lift: 3.129040712912808
# =====================================
# Rule: Jammie Dodgers -> Tiffin
# Support: 0.001088929219600726
# Confidence: 0.05084745762711865
# Lift: 3.502118644067797
# =====================================
# Rule: Jammie Dodgers -> Vegan mincepie
# Support: 0.000544464609800363
# Confidence: 0.025423728813559324
# Lift: 4.669491525423729
# =====================================
# Rule: Spanish Brunch -> Coffee
# Support: 0.0034482758620689655
# Confidence: 0.11309523809523808
# Lift: 3.21213794796269
# =====================================
# Rule: Sandwich -> Lemon and coconut
# Support: 0.0003629764065335753
# Confidence: 0.33333333333333326
# Lift: 5.073664825046039
# =====================================
# Rule: Salad -> Mineral water
# Support: 0.000544464609800363
# Confidence: 0.03296703296703297
# Lift: 3.4273273895915404
# =====================================
# Rule: Tartine -> Mineral water
# Support: 0.0003629764065335753
# Confidence: 0.017241379310344827
# Lift: 3.2758620689655173
# =====================================
# Rule: Vegan mincepie -> Mineral water
# Support: 0.0003629764065335753
# Confidence: 0.017241379310344827
# Lift: 3.166666666666667
# =====================================
# Rule: Pick and Mix Bowls -> Tartine
# Support: 0.000544464609800363
# Confidence: 0.27272727272727276
# Lift: 51.81818181818183
# =====================================
# Rule: Salad -> Spanish Brunch
# Support: 0.0014519056261343012
# Confidence: 0.0879120879120879
# Lift: 4.702869945588392
# =====================================
# Rule: Salad -> Truffles
# Support: 0.0007259528130671506
# Confidence: 0.04395604395604395
# Lift: 3.41123665067327
# =====================================
# Rule: Smoothies -> Coffee
# Support: 0.0009074410163339383
# Confidence: 0.06944444444444445
# Lift: 3.7149406688241644
# =====================================
# Rule: Spanish Brunch -> The Nomad
# Support: 0.001088929219600726
# Confidence: 0.03571428571428571
# Lift: 6.347926267281106
# =====================================
# Rule: Spanish Brunch -> Coffee
# Support: 0.0014519056261343012
# Confidence: 0.047619047619047616
# Lift: 3.6955063715627094
# =====================================
# Rule: Coke -> Cookies
# Support: 0.0003629764065335753
# Confidence: 0.005813953488372092
# Lift: 5.339147286821704
# =====================================
# Rule: Coke -> Crisps
# Support: 0.0003629764065335753
# Confidence: 0.014598540145985401
# Lift: 13.406326034063259
# =====================================
# Rule: Coke -> Sandwich
# Support: 0.0003629764065335753
# Confidence: 0.014598540145985401
# Lift: 10.054744525547445
# =====================================
# Rule: Coke -> Medialuna
# Support: 0.0007259528130671506
# Confidence: 0.029197080291970802
# Lift: 8.043795620437956
# =====================================
# Rule: Coke -> Mineral water
# Support: 0.0003629764065335753
# Confidence: 0.014598540145985401
# Lift: 5.0273722627737225
# =====================================
# Rule: Coke -> Pastry
# Support: 0.0003629764065335753
# Confidence: 0.014598540145985401
# Lift: 3.6562707365627074
# =====================================
# Rule: Coke -> Sandwich
# Support: 0.0018148820326678765
# Confidence: 0.072992700729927
# Lift: 7.312541473125414
# =====================================
# Rule: Tiffin -> Coke
# Support: 0.0003629764065335753
# Confidence: 0.014598540145985401
# Lift: 8.937550689375506
# =====================================
# Rule: Coke -> Truffles
# Support: 0.000544464609800363
# Confidence: 0.021897810218978103
# Lift: 6.35036496350365
# =====================================
# Rule: Coke -> Medialuna
# Support: 0.0003629764065335753
# Confidence: 0.014598540145985401
# Lift: 4.021897810218978
# =====================================
# Rule: Coke -> Mineral water
# Support: 0.001088929219600726
# Confidence: 0.043795620437956206
# Lift: 7.784318342359313
# =====================================
# Rule: Coke -> Mineral water
# Support: 0.000544464609800363
# Confidence: 0.021897810218978103
# Lift: 6.70316301703163
# =====================================
# Rule: Tea -> Coke
# Support: 0.0003629764065335753
# Confidence: 0.014598540145985401
# Lift: 6.703163017031629
# =====================================
# Rule: Coke -> Sandwich
# Support: 0.0003629764065335753
# Confidence: 0.014598540145985401
# Lift: 4.021897810218978
# =====================================
# Rule: Coke -> Pastry
# Support: 0.0003629764065335753
# Confidence: 0.014598540145985401
# Lift: 5.0273722627737225
# =====================================
# Rule: Salad -> Coke
# Support: 0.0003629764065335753
# ...
# Support: 0.0003629764065335753
# Confidence: 0.01176470588235294
# Lift: 16.205882352941174
# =====================================
# Rule: Tea -> Farm House
# Support: 0.0003629764065335753
# Confidence: 0.006578947368421052
# Lift: 5.178571428571428
# =====================================
# Rule: Hot chocolate -> Vegan mincepie
# Support: 0.0003629764065335753
# Confidence: 0.004140786749482401
# Lift: 7.6052449965493425
# =====================================
# Rule: Hot chocolate -> Truffles
# Support: 0.0003629764065335753
# Confidence: 0.005813953488372092
# Lift: 16.017441860465116
# =====================================
# Rule: Hot chocolate -> Sandwich
# Support: 0.000544464609800363
# Confidence: 0.006211180124223603
# Lift: 4.277950310559007
# =====================================
# Rule: Hot chocolate -> Tiffin
# Support: 0.0003629764065335753
# Confidence: 0.014814814814814814
# Lift: 4.296296296296296
# =====================================
# Rule: Pastry -> Tea
# Support: 0.0003629764065335753
# Confidence: 0.0026666666666666666
# Lift: 3.6733333333333333
# =====================================
# Rule: Jammie Dodgers -> Muffin
# Support: 0.000544464609800363
# Confidence: 0.025423728813559324
# Lift: 11.673728813559322
# =====================================
# Rule: Jammie Dodgers -> Tea
# Support: 0.000544464609800363
# Confidence: 0.025423728813559324
# Lift: 7.372881355932204
# =====================================
# Rule: Jammie Dodgers -> Tiffin
# Support: 0.0003629764065335753
# Confidence: 0.01694915254237288
# Lift: 15.564971751412427
# =====================================
# Rule: Jammie Dodgers -> Tea
# Support: 0.0003629764065335753
# Confidence: 0.01694915254237288
# Lift: 3.4588826114249844
# =====================================
# Rule: Jammie Dodgers -> Sandwich
# Support: 0.0003629764065335753
# Confidence: 0.01694915254237288
# Lift: 15.564971751412427
# =====================================
# Rule: Jammie Dodgers -> Tiffin
# Support: 0.0003629764065335753
# Confidence: 0.01694915254237288
# Lift: 5.836864406779662
# =====================================
# Rule: Truffles -> Medialuna
# Support: 0.000544464609800363
# Confidence: 0.00872093023255814
# Lift: 12.013081395348838
# =====================================
# Rule: Sandwich -> Mineral water
# Support: 0.0007259528130671506
# Confidence: 0.011627906976744184
# Lift: 4.57641196013289
# =====================================
# Rule: Soup -> Mineral water
# Support: 0.0003629764065335753
# Confidence: 0.005813953488372092
# Lift: 4.004360465116279
# =====================================
# Rule: Tea -> Muffin
# Support: 0.0007259528130671506
# Confidence: 0.012345679012345678
# Lift: 3.580246913580247
# =====================================
# Rule: Truffles -> Pastry
# Support: 0.0003629764065335753
# Confidence: 0.005813953488372092
# Lift: 3.559431524547803
# =====================================
# Rule: Salad -> Sandwich
# Support: 0.0003629764065335753
# Confidence: 0.021978021978021976
# Lift: 4.657650042265426
# =====================================
# Rule: Salad -> Spanish Brunch
# Support: 0.0003629764065335753
# Confidence: 0.005813953488372092
# Lift: 4.004360465116279
# =====================================
# Rule: Sandwich -> Spanish Brunch
# Support: 0.0003629764065335753
# Confidence: 0.010309278350515464
# Lift: 3.1557846506300113
# =====================================
# Rule: Sandwich -> Toast
# Support: 0.0003629764065335753
# Confidence: 0.005813953488372092
# Lift: 4.004360465116279
# =====================================
# Rule: Truffles -> Sandwich
# Support: 0.0007259528130671506
# Confidence: 0.011627906976744184
# Lift: 3.2034883720930227
# =====================================
# Rule: Scone -> Truffles
# Support: 0.0003629764065335753
# Confidence: 0.005813953488372092
# Lift: 8.008720930232558
# =====================================
# Rule: Spanish Brunch -> Tea
# Support: 0.0003629764065335753
# Confidence: 0.011904761904761904
# Lift: 3.452380952380952
# =====================================
# Rule: Spanish Brunch -> Toast
# Support: 0.0003629764065335753
# Confidence: 0.005813953488372092
# Lift: 4.57641196013289
# =====================================
# Rule: Tiffin -> Tea
# Support: 0.0003629764065335753
# Confidence: 0.014814814814814814
# Lift: 4.296296296296296
# =====================================
# Rule: Sandwich -> Medialuna
# Support: 0.0003629764065335753
# Confidence: 0.011235955056179775
# Lift: 3.095505617977528
# =====================================
# Rule: Sandwich -> Medialuna
# Support: 0.0003629764065335753
# Confidence: 0.003262642740619902
# Lift: 3.595432300163132
# =====================================
# Rule: Tiffin -> Sandwich
# Support: 0.0003629764065335753
# Confidence: 0.0037878787878787876
# Lift: 3.478535353535353
# =====================================
# Rule: Tea -> Soup
# Support: 0.0003629764065335753
# Confidence: 0.004246284501061571
# Lift: 3.3424325144070366
# =====================================
# Rule: Sandwich -> Mineral water
# Support: 0.000544464609800363
# Confidence: 0.025862068965517244
# Lift: 4.1911764705882355
# =====================================
# Rule: Sandwich -> Mineral water
# Support: 0.0003629764065335753
# Confidence: 0.017241379310344827
# Lift: 4.75
# =====================================
# Rule: Sandwich -> Pastry
# Support: 0.000544464609800363
# Confidence: 0.017142857142857144
# Lift: 10.495238095238095
# =====================================
# Rule: Tiffin -> Pastry
# Support: 0.000544464609800363
# Confidence: 0.002622377622377623
# Lift: 4.816433566433567
# =====================================
# Rule: Salad -> Sandwich
# Support: 0.0003629764065335753
# Confidence: 0.021978021978021976
# Lift: 6.054945054945055
# =====================================
# Rule: Salad -> Soup
# Support: 0.0003629764065335753
# Confidence: 0.021978021978021976
# Lift: 17.299843014128726
# =====================================
# Rule: Salad -> Spanish Brunch
# Support: 0.0003629764065335753
# Confidence: 0.021978021978021976
# Lift: 8.649921507064363
# =====================================
# Rule: Truffles -> Sandwich
# Support: 0.0003629764065335753
# Confidence: 0.003262642740619902
# Lift: 5.992387166938553
# =====================================
# Rule: Truffles -> Sandwich
# Support: 0.0007259528130671506
# Confidence: 0.006525285481239804
# Lift: 4.494290375203915
# =====================================
# Rule: Scone -> Tea
# Support: 0.0003629764065335753
# Confidence: 0.0066006600660066
# Lift: 6.06160616061606
# =====================================
# Rule: Tiffin -> Scone
# Support: 0.0003629764065335753
# Confidence: 0.004246284501061571
# Lift: 3.3424325144070366
# =====================================
# Rule: Truffles -> Coke
# Support: 0.0003629764065335753
# Confidence: 0.014598540145985401
# Lift: 16.087591240875913
# =====================================
# Rule: Coke -> Mineral water
# Support: 0.0003629764065335753
# Confidence: 0.014598540145985401
# Lift: 20.10948905109489
# =====================================
# Rule: Coke -> Tea
# Support: 0.0003629764065335753
# Confidence: 0.014598540145985401
# Lift: 5.362530413625304
# =====================================
# Rule: Hot chocolate -> Tea
# Support: 0.0003629764065335753
# Confidence: 0.00425531914893617
# Lift: 3.907801418439716
# =====================================
# Rule: Hot chocolate -> Sandwich
# Support: 0.0003629764065335753
# Confidence: 0.00425531914893617
# Lift: 3.907801418439716
# =====================================
# Rule: Hot chocolate -> Tea
# Support: 0.0003629764065335753
# Confidence: 0.00425531914893617
# Lift: 5.861702127659575
# =====================================
# Rule: Sandwich -> Tea
# Support: 0.000544464609800363
# Confidence: 0.006382978723404256
# Lift: 3.9078014184397167
# =====================================
# Rule: Salad -> Soup
# Support: 0.0003629764065335753
# Confidence: 0.00425531914893617
# Lift: 11.72340425531915
# =====================================
# Rule: Sandwich -> Tea
# Support: 0.0003629764065335753
# Confidence: 0.006993006993006993
# Lift: 4.816433566433567
# =====================================
# Rule: Salad -> Extra Salami or Feta
# Support: 0.0003629764065335753
# Confidence: 0.05405405405405405
# Lift: 148.9189189189189
# =====================================
# Rule: Hot chocolate -> Pastry
# Support: 0.0003629764065335753
# Confidence: 0.01176470588235294
# Lift: 9.260504201680671
# =====================================
# Rule: Hot chocolate -> Granola
# Support: 0.0003629764065335753
# Confidence: 0.07692307692307691
# Lift: 47.09401709401709
# =====================================
# Rule: Hot chocolate -> Sandwich
# Support: 0.0003629764065335753
# Confidence: 0.004140786749482401
# Lift: 5.703933747412008
# =====================================
# Rule: Hot chocolate -> Tea
# Support: 0.0003629764065335753
# Confidence: 0.004140786749482401
# Lift: 11.407867494824016
# =====================================
# Rule: Hot chocolate -> Medialuna
# Support: 0.0003629764065335753
# Confidence: 0.004140786749482401
# Lift: 11.407867494824016
# =====================================
# Rule: Hot chocolate -> Pastry
# Support: 0.0003629764065335753
# Confidence: 0.004140786749482401
# Lift: 4.563146997929606
# =====================================
# Rule: Hot chocolate -> Sandwich
# Support: 0.0003629764065335753
# Confidence: 0.004140786749482401
# Lift: 4.563146997929606
# =====================================
# Rule: Sandwich -> Tea
# Support: 0.0003629764065335753
# Confidence: 0.005813953488372092
# Lift: 5.339147286821704
# =====================================
# Rule: Tea -> Sandwich
# Support: 0.0003629764065335753
# Confidence: 0.003262642740619902
# Lift: 4.494290375203915
# =====================================
# Rule: Bread -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.006269592476489028
# Lift: 6.909090909090909
# =====================================
# Rule: Bread -> Tea
# Support: 0.0003629764065335753
# Confidence: 0.006269592476489028
# Lift: 17.272727272727273
# =====================================
# Rule: Bread -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.006269592476489028
# Lift: 6.909090909090909
# =====================================
# Rule: Bread -> Medialuna
# Support: 0.0003629764065335753
# Confidence: 0.006269592476489028
# Lift: 17.272727272727273
# =====================================
# Rule: Coffee -> Cookies
# Support: 0.0003629764065335753
# Confidence: 0.006269592476489028
# Lift: 5.757575757575757
# =====================================
# Rule: Alfajores -> Coffee
# Support: 0.000544464609800363
# Confidence: 0.009404388714733543
# Lift: 12.954545454545457
# =====================================
# Rule: Coffee -> Cookies
# Support: 0.0003629764065335753
# Confidence: 0.006269592476489028
# Lift: 17.272727272727273
# =====================================
# Rule: Coffee -> Hot chocolate
# Support: 0.0003629764065335753
# Confidence: 0.006269592476489028
# Lift: 8.636363636363637
# =====================================
# Rule: Pastry -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.006269592476489028
# Lift: 11.515151515151514
# =====================================
# Rule: Bread -> Cake
# Support: 0.0003629764065335753
# Confidence: 0.005797101449275362
# Lift: 7.985507246376812
# =====================================
# Rule: Bread -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.002262443438914027
# Lift: 3.1165158371040724
# =====================================
# Rule: Bread -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.002262443438914027
# Lift: 4.155354449472096
# =====================================
# Rule: Bread -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.004140786749482401
# Lift: 11.407867494824016
# =====================================
# Rule: Jammie Dodgers -> Bread
# Support: 0.0003629764065335753
# Confidence: 0.01694915254237288
# Lift: 7.183833116036506
# =====================================
# Rule: Bread -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.0037878787878787876
# Lift: 4.174242424242424
# =====================================
# Rule: Bread -> Pastry
# Support: 0.000544464609800363
# Confidence: 0.061224489795918366
# Lift: 4.819241982507289
# =====================================
# Rule: Bread -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.014814814814814814
# Lift: 6.279202279202279
# =====================================
# Rule: Bread -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.019047619047619046
# Lift: 14.993197278911563
# =====================================
# Rule: Bread -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.00425531914893617
# Lift: 3.349544072948328
# =====================================
# Rule: Bread -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.16666666666666663
# Lift: 306.11111111111103
# =====================================
# Rule: Bread -> Pastry
# Support: 0.0003629764065335753
# Confidence: 0.01176470588235294
# Lift: 5.893048128342246
# =====================================
# Rule: Jammie Dodgers -> Bread
# Support: 0.0003629764065335753
# Confidence: 0.01694915254237288
# Lift: 13.341404358353511
# =====================================
# Rule: Bread -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.0037878787878787876
# Lift: 5.21780303030303
# =====================================
# Rule: Bread -> Coffee
# Support: 0.000544464609800363
# Confidence: 0.005681818181818182
# Lift: 5.21780303030303
# =====================================
# Rule: Bread -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.0037878787878787876
# Lift: 6.957070707070706
# =====================================
# Rule: Bread -> Soup
# Support: 0.0003629764065335753
# Confidence: 0.00425531914893617
# Lift: 11.72340425531915
# =====================================
# Rule: Coffee -> Cake
# Support: 0.0003629764065335753
# Confidence: 0.002262443438914027
# Lift: 6.233031674208145
# =====================================
# Rule: Coffee -> Cake
# Support: 0.0003629764065335753
# Confidence: 0.002262443438914027
# Lift: 6.233031674208145
# =====================================
# Rule: Coffee -> Cake
# Support: 0.000544464609800363
# Confidence: 0.0033936651583710412
# Lift: 3.1165158371040724
# =====================================
# Rule: Coffee -> Cake
# Support: 0.0003629764065335753
# Confidence: 0.002262443438914027
# Lift: 6.233031674208145
# =====================================
# Rule: Coffee -> Cake
# Support: 0.0003629764065335753
# Confidence: 0.002262443438914027
# Lift: 3.1165158371040724
# =====================================
# Rule: Coffee -> Cake
# Support: 0.0003629764065335753
# Confidence: 0.002262443438914027
# Lift: 6.233031674208145
# =====================================
# Rule: Coffee -> Cake
# Support: 0.0003629764065335753
# Confidence: 0.002262443438914027
# Lift: 4.155354449472096
# =====================================
# Rule: Coffee -> Cake
# Support: 0.0003629764065335753
# Confidence: 0.002262443438914027
# Lift: 3.1165158371040724
# =====================================
# Rule: Coffee -> Cake
# Support: 0.0003629764065335753
# Confidence: 0.002262443438914027
# Lift: 4.155354449472096
# =====================================
# Rule: Coffee -> Cake
# Support: 0.0007259528130671506
# Confidence: 0.004524886877828054
# Lift: 3.561732385261797
# =====================================
# Rule: Cake -> Soup
# Support: 0.0003629764065335753
# Confidence: 0.002262443438914027
# Lift: 6.233031674208145
# =====================================
# Rule: Coffee -> Chicken Stew
# Support: 0.0003629764065335753
# Confidence: 0.019047619047619046
# Lift: 20.99047619047619
# =====================================
# Rule: Coffee -> Chicken Stew
# Support: 0.0003629764065335753
# Confidence: 0.019047619047619046
# Lift: 26.238095238095237
# =====================================
# Rule: Coffee -> Sandwich
# Support: 0.0003629764065335753
# Confidence: 0.014598540145985401
# Lift: 20.10948905109489
# =====================================
# Rule: Coffee -> Cookies
# Support: 0.0003629764065335753
# Confidence: 0.00425531914893617
# Lift: 7.815602836879432
# =====================================
# Rule: Coffee -> Soup
# Support: 0.0003629764065335753
# Confidence: 0.00425531914893617
# Lift: 3.349544072948328
# =====================================
# Rule: Spanish Brunch -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.05405405405405405
# Lift: 148.9189189189189
# =====================================
# Rule: Pastry -> Coffee
# Support: 0.0003629764065335753
# Confidence: 0.01176470588235294
# Lift: 10.803921568627448
# =====================================
# Rule: Coffee -> Cake
# Support: 0.0003629764065335753
# Confidence: 0.002262443438914027
# Lift: 6.233031674208145
# =====================================

# %%
association_results
# Out:
# [RelationRecord(items=frozenset({'Argentina Night', 'Afternoon with the baker'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Afternoon with the baker'}), items_add=frozenset({'Argentina Night'}), confidence=0.16666666666666663, lift=229.5833333333333), OrderedStatistic(items_base=frozenset({'Argentina Night'}), items_add=frozenset({'Afternoon with the baker'}), confidence=0.5, lift=229.58333333333331)]),
#  RelationRecord(items=frozenset({'Afternoon with the baker', 'Spanish Brunch'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Afternoon with the baker'}), items_add=frozenset({'Spanish Brunch'}), confidence=0.16666666666666663, lift=5.46626984126984), OrderedStatistic(items_base=frozenset({'Spanish Brunch'}), items_add=frozenset({'Afternoon with the baker'}), confidence=0.011904761904761904, lift=5.466269841269841)]),
#  RelationRecord(items=frozenset({'Crepes', 'Alfajores'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Alfajores'}), items_add=frozenset({'Crepes'}), confidence=0.006269592476489028, lift=5.757575757575757), OrderedStatistic(items_base=frozenset({'Crepes'}), items_add=frozenset({'Alfajores'}), confidence=0.33333333333333326, lift=5.757575757575756)]),
#  RelationRecord(items=frozenset({'Dulce de Leche', 'Alfajores'}), support=0.000544464609800363, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Alfajores'}), items_add=frozenset({'Dulce de Leche'}), confidence=0.009404388714733543, lift=5.757575757575758), OrderedStatistic(items_base=frozenset({'Dulce de Leche'}), items_add=frozenset({'Alfajores'}), confidence=0.33333333333333337, lift=5.757575757575759)]),
#  RelationRecord(items=frozenset({'Frittata', 'Art Tray'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Art Tray'}), items_add=frozenset({'Frittata'}), confidence=0.05405405405405405, lift=3.918918918918919), OrderedStatistic(items_base=frozenset({'Frittata'}), items_add=frozenset({'Art Tray'}), confidence=0.02631578947368421, lift=3.918918918918919)]),
#  RelationRecord(items=frozenset({'Hack the stack', 'Art Tray'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Art Tray'}), items_add=frozenset({'Hack the stack'}), confidence=0.05405405405405405, lift=148.9189189189189), OrderedStatistic(items_base=frozenset({'Hack the stack'}), items_add=frozenset({'Art Tray'}), confidence=1.0, lift=148.9189189189189)]),
#  RelationRecord(items=frozenset({'Art Tray', 'Hearty & Seasonal'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Art Tray'}), items_add=frozenset({'Hearty & Seasonal'}), confidence=0.05405405405405405, lift=3.2729432729432726), OrderedStatistic(items_base=frozenset({'Hearty & Seasonal'}), items_add=frozenset({'Art Tray'}), confidence=0.021978021978021976, lift=3.2729432729432726)]),
#  RelationRecord(items=frozenset({'Juice', 'Art Tray'}), support=0.0012704174228675136, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Art Tray'}), items_add=frozenset({'Juice'}), confidence=0.1891891891891892, lift=3.0303268384663733), OrderedStatistic(items_base=frozenset({'Juice'}), items_add=frozenset({'Art Tray'}), confidence=0.020348837209302324, lift=3.030326838466373)]),
#  RelationRecord(items=frozenset({'Art Tray', 'My-5 Fruit Shoot'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Art Tray'}), items_add=frozenset({'My-5 Fruit Shoot'}), confidence=0.05405405405405405, lift=16.546546546546544), OrderedStatistic(items_base=frozenset({'My-5 Fruit Shoot'}), items_add=frozenset({'Art Tray'}), confidence=0.1111111111111111, lift=16.546546546546544)]),
#  RelationRecord(items=frozenset({'Salad', 'Art Tray'}), support=0.000544464609800363, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Art Tray'}), items_add=frozenset({'Salad'}), confidence=0.08108108108108109, lift=4.9094149094149095), OrderedStatistic(items_base=frozenset({'Salad'}), items_add=frozenset({'Art Tray'}), confidence=0.03296703296703297, lift=4.9094149094149095)]),
#  RelationRecord(items=frozenset({'Soup', 'Art Tray'}), support=0.001088929219600726, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Art Tray'}), items_add=frozenset({'Soup'}), confidence=0.16216216216216217, lift=3.1241731241731245), OrderedStatistic(items_base=frozenset({'Soup'}), items_add=frozenset({'Art Tray'}), confidence=0.020979020979020983, lift=3.124173124173125)]),
#  RelationRecord(items=frozenset({'Spanish Brunch', 'Art Tray'}), support=0.0007259528130671506, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Art Tray'}), items_add=frozenset({'Spanish Brunch'}), confidence=0.1081081081081081, lift=3.545688545688545), OrderedStatistic(items_base=frozenset({'Spanish Brunch'}), items_add=frozenset({'Art Tray'}), confidence=0.023809523809523808, lift=3.5456885456885456)]),
#  RelationRecord(items=frozenset({'Baguette', 'Scandinavian'}), support=0.001633393829401089, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Baguette'}), items_add=frozenset({'Scandinavian'}), confidence=0.10227272727272728, lift=3.522017045454546), OrderedStatistic(items_base=frozenset({'Scandinavian'}), items_add=frozenset({'Baguette'}), confidence=0.05625, lift=3.522017045454546)]),
#  RelationRecord(items=frozenset({'Cookies', 'Bare Popcorn'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Bare Popcorn'}), items_add=frozenset({'Cookies'}), confidence=0.5, lift=5.861702127659575), OrderedStatistic(items_base=frozenset({'Cookies'}), items_add=frozenset({'Bare Popcorn'}), confidence=0.00425531914893617, lift=5.861702127659575)]),
#  RelationRecord(items=frozenset({'Juice', 'Bare Popcorn'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Bare Popcorn'}), items_add=frozenset({'Juice'}), confidence=0.5, lift=8.008720930232558), OrderedStatistic(items_base=frozenset({'Juice'}), items_add=frozenset({'Bare Popcorn'}), confidence=0.005813953488372092, lift=8.008720930232558)]),
#  RelationRecord(items=frozenset({'Hot chocolate', 'Basket'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Basket'}), items_add=frozenset({'Hot chocolate'}), confidence=0.39999999999999997, lift=4.563146997929606), OrderedStatistic(items_base=frozenset({'Hot chocolate'}), items_add=frozenset({'Basket'}), confidence=0.004140786749482401, lift=4.563146997929606)]),
#  RelationRecord(items=frozenset({'Brownie', 'My-5 Fruit Shoot'}), support=0.0007259528130671506, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Brownie'}), items_add=frozenset({'My-5 Fruit Shoot'}), confidence=0.011594202898550725, lift=3.549114331723027), OrderedStatistic(items_base=frozenset({'My-5 Fruit Shoot'}), items_add=frozenset({'Brownie'}), confidence=0.2222222222222222, lift=3.5491143317230276)]),
#  RelationRecord(items=frozenset({'Coke', 'Chicken Stew'}), support=0.0018148820326678765, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Chicken Stew'}), items_add=frozenset({'Coke'}), confidence=0.09523809523809525, lift=3.830378866875218), OrderedStatistic(items_base=frozenset({'Coke'}), items_add=frozenset({'Chicken Stew'}), confidence=0.072992700729927, lift=3.830378866875217)]),
#  RelationRecord(items=frozenset({'Granola', 'Chicken Stew'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Chicken Stew'}), items_add=frozenset({'Granola'}), confidence=0.019047619047619046, lift=4.0366300366300365), OrderedStatistic(items_base=frozenset({'Granola'}), items_add=frozenset({'Chicken Stew'}), confidence=0.07692307692307691, lift=4.0366300366300365)]),
#  RelationRecord(items=frozenset({'Spanish Brunch', 'Chicken Stew'}), support=0.001996370235934664, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Chicken Stew'}), items_add=frozenset({'Spanish Brunch'}), confidence=0.10476190476190476, lift=3.4359410430839), OrderedStatistic(items_base=frozenset({'Spanish Brunch'}), items_add=frozenset({'Chicken Stew'}), confidence=0.06547619047619047, lift=3.4359410430838997)]),
#  RelationRecord(items=frozenset({'Coke', 'Chocolates'}), support=0.000544464609800363, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Chocolates'}), items_add=frozenset({'Coke'}), confidence=0.33333333333333337, lift=13.406326034063262), OrderedStatistic(items_base=frozenset({'Coke'}), items_add=frozenset({'Chocolates'}), confidence=0.021897810218978103, lift=13.40632603406326)]),
#  RelationRecord(items=frozenset({'Hot chocolate', 'Chocolates'}), support=0.0007259528130671506, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Chocolates'}), items_add=frozenset({'Hot chocolate'}), confidence=0.4444444444444444, lift=5.070163331032895), OrderedStatistic(items_base=frozenset({'Hot chocolate'}), items_add=frozenset({'Chocolates'}), confidence=0.008281573498964802, lift=5.070163331032895)]),
#  RelationRecord(items=frozenset({'Chocolates', 'Juice'}), support=0.0007259528130671506, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Chocolates'}), items_add=frozenset({'Juice'}), confidence=0.4444444444444444, lift=7.118863049095607), OrderedStatistic(items_base=frozenset({'Juice'}), items_add=frozenset({'Chocolates'}), confidence=0.011627906976744184, lift=7.118863049095606)]),
#  RelationRecord(items=frozenset({'Christmas common', 'Jam'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Christmas common'}), items_add=frozenset({'Jam'}), confidence=0.39999999999999997, lift=21.398058252427184), OrderedStatistic(items_base=frozenset({'Jam'}), items_add=frozenset({'Christmas common'}), confidence=0.019417475728155338, lift=21.398058252427184)]),
#  RelationRecord(items=frozenset({'Coke', 'Crisps'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Coke'}), items_add=frozenset({'Crisps'}), confidence=0.014598540145985401, lift=6.703163017031629), OrderedStatistic(items_base=frozenset({'Crisps'}), items_add=frozenset({'Coke'}), confidence=0.16666666666666663, lift=6.7031630170316285)]),
#  RelationRecord(items=frozenset({'Coke', 'Mineral water'}), support=0.001996370235934664, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Coke'}), items_add=frozenset({'Mineral water'}), confidence=0.08029197080291971, lift=3.8138686131386863), OrderedStatistic(items_base=frozenset({'Mineral water'}), items_add=frozenset({'Coke'}), confidence=0.09482758620689655, lift=3.813868613138686)]),
#  RelationRecord(items=frozenset({'Salad', 'Coke'}), support=0.0012704174228675136, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Coke'}), items_add=frozenset({'Salad'}), confidence=0.051094890510948905, lift=3.0937675463222907), OrderedStatistic(items_base=frozenset({'Salad'}), items_add=frozenset({'Coke'}), confidence=0.07692307692307693, lift=3.093767546322291)]),
#  RelationRecord(items=frozenset({'Coke', 'Sandwich'}), support=0.008892921960072596, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Coke'}), items_add=frozenset({'Sandwich'}), confidence=0.35766423357664234, lift=3.2148938450363773), OrderedStatistic(items_base=frozenset({'Sandwich'}), items_add=frozenset({'Coke'}), confidence=0.0799347471451876, lift=3.2148938450363773)]),
#  RelationRecord(items=frozenset({'Tacos/Fajita', 'Coke'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Coke'}), items_add=frozenset({'Tacos/Fajita'}), confidence=0.014598540145985401, lift=7.312541473125415), OrderedStatistic(items_base=frozenset({'Tacos/Fajita'}), items_add=frozenset({'Coke'}), confidence=0.18181818181818182, lift=7.312541473125415)]),
#  RelationRecord(items=frozenset({'Vegan Feast', 'Cookies'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cookies'}), items_add=frozenset({'Vegan Feast'}), confidence=0.00425531914893617, lift=3.907801418439716), OrderedStatistic(items_base=frozenset({'Vegan Feast'}), items_add=frozenset({'Cookies'}), confidence=0.33333333333333326, lift=3.9078014184397154)]),
#  RelationRecord(items=frozenset({'Medialuna', 'Crepes'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Crepes'}), items_add=frozenset({'Medialuna'}), confidence=0.33333333333333326, lift=3.4785353535353525), OrderedStatistic(items_base=frozenset({'Medialuna'}), items_add=frozenset({'Crepes'}), confidence=0.0037878787878787876, lift=3.478535353535353)]),
#  RelationRecord(items=frozenset({'Crisps', 'Frittata'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Crisps'}), items_add=frozenset({'Frittata'}), confidence=0.16666666666666663, lift=12.08333333333333), OrderedStatistic(items_base=frozenset({'Frittata'}), items_add=frozenset({'Crisps'}), confidence=0.02631578947368421, lift=12.083333333333332)]),
#  RelationRecord(items=frozenset({'Crisps', 'Juice'}), support=0.001088929219600726, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Crisps'}), items_add=frozenset({'Juice'}), confidence=0.5, lift=8.008720930232558), OrderedStatistic(items_base=frozenset({'Juice'}), items_add=frozenset({'Crisps'}), confidence=0.01744186046511628, lift=8.008720930232558)]),
#  RelationRecord(items=frozenset({'Mineral water', 'Crisps'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Crisps'}), items_add=frozenset({'Mineral water'}), confidence=0.16666666666666663, lift=7.916666666666665), OrderedStatistic(items_base=frozenset({'Mineral water'}), items_add=frozenset({'Crisps'}), confidence=0.017241379310344827, lift=7.916666666666666)]),
#  RelationRecord(items=frozenset({'Sandwich', 'Crisps'}), support=0.001088929219600726, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Crisps'}), items_add=frozenset({'Sandwich'}), confidence=0.5, lift=4.494290375203915), OrderedStatistic(items_base=frozenset({'Sandwich'}), items_add=frozenset({'Crisps'}), confidence=0.009787928221859707, lift=4.494290375203915)]),
#  RelationRecord(items=frozenset({'Crisps', 'Truffles'}), support=0.000544464609800363, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Crisps'}), items_add=frozenset({'Truffles'}), confidence=0.25, lift=7.871428571428572), OrderedStatistic(items_base=frozenset({'Truffles'}), items_add=frozenset({'Crisps'}), confidence=0.017142857142857144, lift=7.871428571428571)]),
#  RelationRecord(items=frozenset({'Drinking chocolate spoons ', 'Juice'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Drinking chocolate spoons '}), items_add=frozenset({'Juice'}), confidence=0.25, lift=4.004360465116279), OrderedStatistic(items_base=frozenset({'Juice'}), items_add=frozenset({'Drinking chocolate spoons '}), confidence=0.005813953488372092, lift=4.004360465116279)]),
#  RelationRecord(items=frozenset({'Drinking chocolate spoons ', 'Mineral water'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Drinking chocolate spoons '}), items_add=frozenset({'Mineral water'}), confidence=0.25, lift=11.875), OrderedStatistic(items_base=frozenset({'Mineral water'}), items_add=frozenset({'Drinking chocolate spoons '}), confidence=0.017241379310344827, lift=11.875)]),
#  RelationRecord(items=frozenset({'Extra Salami or Feta', 'Duck egg'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Duck egg'}), items_add=frozenset({'Extra Salami or Feta'}), confidence=0.16666666666666663, lift=24.819819819819813), OrderedStatistic(items_base=frozenset({'Extra Salami or Feta'}), items_add=frozenset({'Duck egg'}), confidence=0.05405405405405405, lift=24.819819819819816)]),
#  RelationRecord(items=frozenset({'Duck egg', 'Spanish Brunch'}), support=0.001088929219600726, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Duck egg'}), items_add=frozenset({'Spanish Brunch'}), confidence=0.5, lift=16.398809523809522), OrderedStatistic(items_base=frozenset({'Spanish Brunch'}), items_add=frozenset({'Duck egg'}), confidence=0.03571428571428571, lift=16.398809523809522)]),
#  RelationRecord(items=frozenset({'Duck egg', 'Truffles'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Duck egg'}), items_add=frozenset({'Truffles'}), confidence=0.16666666666666663, lift=5.247619047619047), OrderedStatistic(items_base=frozenset({'Truffles'}), items_add=frozenset({'Duck egg'}), confidence=0.011428571428571429, lift=5.247619047619048)]),
#  RelationRecord(items=frozenset({'Fudge', 'Dulce de Leche'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Dulce de Leche'}), items_add=frozenset({'Fudge'}), confidence=0.2222222222222222, lift=13.309178743961354), OrderedStatistic(items_base=frozenset({'Fudge'}), items_add=frozenset({'Dulce de Leche'}), confidence=0.021739130434782608, lift=13.309178743961352)]),
#  RelationRecord(items=frozenset({'Fudge', 'Eggs'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Eggs'}), items_add=frozenset({'Fudge'}), confidence=0.09090909090909091, lift=5.444664031620554), OrderedStatistic(items_base=frozenset({'Fudge'}), items_add=frozenset({'Eggs'}), confidence=0.021739130434782608, lift=5.444664031620554)]),
#  RelationRecord(items=frozenset({'Scandinavian', 'Eggs'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Eggs'}), items_add=frozenset({'Scandinavian'}), confidence=0.09090909090909091, lift=3.1306818181818183), OrderedStatistic(items_base=frozenset({'Scandinavian'}), items_add=frozenset({'Eggs'}), confidence=0.012499999999999999, lift=3.1306818181818183)]),
#  RelationRecord(items=frozenset({'Jam', "Ella's Kitchen Pouches"}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({"Ella's Kitchen Pouches"}), items_add=frozenset({'Jam'}), confidence=0.13333333333333333, lift=7.132686084142395), OrderedStatistic(items_base=frozenset({'Jam'}), items_add=frozenset({"Ella's Kitchen Pouches"}), confidence=0.019417475728155338, lift=7.132686084142395)]),
#  RelationRecord(items=frozenset({"Ella's Kitchen Pouches", 'Juice'}), support=0.001088929219600726, ordered_statistics=[OrderedStatistic(items_base=frozenset({"Ella's Kitchen Pouches"}), items_add=frozenset({'Juice'}), confidence=0.4, lift=6.406976744186046), OrderedStatistic(items_base=frozenset({'Juice'}), items_add=frozenset({"Ella's Kitchen Pouches"}), confidence=0.01744186046511628, lift=6.406976744186046)]),
#  RelationRecord(items=frozenset({'Salad', 'Extra Salami or Feta'}), support=0.0029038112522686023, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Extra Salami or Feta'}), items_add=frozenset({'Salad'}), confidence=0.4324324324324324, lift=26.18354618354618), OrderedStatistic(items_base=frozenset({'Salad'}), items_add=frozenset({'Extra Salami or Feta'}), confidence=0.1758241758241758, lift=26.18354618354618)]),
#  RelationRecord(items=frozenset({'Extra Salami or Feta', 'Spanish Brunch'}), support=0.0014519056261343012, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Extra Salami or Feta'}), items_add=frozenset({'Spanish Brunch'}), confidence=0.2162162162162162, lift=7.09137709137709), OrderedStatistic(items_base=frozenset({'Spanish Brunch'}), items_add=frozenset({'Extra Salami or Feta'}), confidence=0.047619047619047616, lift=7.091377091377091)]),
#  RelationRecord(items=frozenset({'Farm House', 'Focaccia'}), support=0.0007259528130671506, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Farm House'}), items_add=frozenset({'Focaccia'}), confidence=0.02352941176470588, lift=3.0868347338935567), OrderedStatistic(items_base=frozenset({'Focaccia'}), items_add=frozenset({'Farm House'}), confidence=0.09523809523809523, lift=3.086834733893557)]),
#  RelationRecord(items=frozenset({'Farm House', 'Scandinavian'}), support=0.0029038112522686023, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Farm House'}), items_add=frozenset({'Scandinavian'}), confidence=0.09411764705882351, lift=3.241176470588235), OrderedStatistic(items_base=frozenset({'Scandinavian'}), items_add=frozenset({'Farm House'}), confidence=0.09999999999999999, lift=3.241176470588235)]),
#  RelationRecord(items=frozenset({'Fudge', 'Focaccia'}), support=0.0007259528130671506, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Focaccia'}), items_add=frozenset({'Fudge'}), confidence=0.09523809523809523, lift=5.703933747412009), OrderedStatistic(items_base=frozenset({'Fudge'}), items_add=frozenset({'Focaccia'}), confidence=0.043478260869565216, lift=5.703933747412008)]),
#  RelationRecord(items=frozenset({'Focaccia', 'Scandinavian'}), support=0.0007259528130671506, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Focaccia'}), items_add=frozenset({'Scandinavian'}), confidence=0.09523809523809523, lift=3.2797619047619047), OrderedStatistic(items_base=frozenset({'Scandinavian'}), items_add=frozenset({'Focaccia'}), confidence=0.024999999999999998, lift=3.279761904761904)]),
#  RelationRecord(items=frozenset({'Mineral water', 'Frittata'}), support=0.001088929219600726, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Frittata'}), items_add=frozenset({'Mineral water'}), confidence=0.07894736842105264, lift=3.7500000000000004), OrderedStatistic(items_base=frozenset({'Mineral water'}), items_add=frozenset({'Frittata'}), confidence=0.05172413793103449, lift=3.7500000000000004)]),
#  RelationRecord(items=frozenset({'Fudge', 'Jam'}), support=0.004355716878402904, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Fudge'}), items_add=frozenset({'Jam'}), confidence=0.26086956521739135, lift=13.955255382017732), OrderedStatistic(items_base=frozenset({'Jam'}), items_add=frozenset({'Fudge'}), confidence=0.2330097087378641, lift=13.955255382017732)]),
#  RelationRecord(items=frozenset({'Half slice Monster ', 'Juice'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Half slice Monster '}), items_add=frozenset({'Juice'}), confidence=0.5, lift=8.008720930232558), OrderedStatistic(items_base=frozenset({'Juice'}), items_add=frozenset({'Half slice Monster '}), confidence=0.005813953488372092, lift=8.008720930232558)]),
#  RelationRecord(items=frozenset({'Mighty Protein', 'Hearty & Seasonal'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Hearty & Seasonal'}), items_add=frozenset({'Mighty Protein'}), confidence=0.021978021978021976, lift=11.008991008991009), OrderedStatistic(items_base=frozenset({'Mighty Protein'}), items_add=frozenset({'Hearty & Seasonal'}), confidence=0.18181818181818182, lift=11.008991008991009)]),
#  RelationRecord(items=frozenset({'Mineral water', 'Hearty & Seasonal'}), support=0.001633393829401089, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Hearty & Seasonal'}), items_add=frozenset({'Mineral water'}), confidence=0.0989010989010989, lift=4.697802197802198), OrderedStatistic(items_base=frozenset({'Mineral water'}), items_add=frozenset({'Hearty & Seasonal'}), confidence=0.07758620689655173, lift=4.697802197802198)]),
#  RelationRecord(items=frozenset({'Pick and Mix Bowls', 'Hearty & Seasonal'}), support=0.000544464609800363, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Hearty & Seasonal'}), items_add=frozenset({'Pick and Mix Bowls'}), confidence=0.03296703296703297, lift=16.513486513486516), OrderedStatistic(items_base=frozenset({'Pick and Mix Bowls'}), items_add=frozenset({'Hearty & Seasonal'}), confidence=0.27272727272727276, lift=16.513486513486516)]),
#  RelationRecord(items=frozenset({'Smoothies', 'Hearty & Seasonal'}), support=0.0009074410163339383, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Hearty & Seasonal'}), items_add=frozenset({'Smoothies'}), confidence=0.054945054945054944, lift=4.204822954822955), OrderedStatistic(items_base=frozenset({'Smoothies'}), items_add=frozenset({'Hearty & Seasonal'}), confidence=0.06944444444444445, lift=4.204822954822955)]),
#  RelationRecord(items=frozenset({'Pick and Mix Bowls', 'Jam'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jam'}), items_add=frozenset({'Pick and Mix Bowls'}), confidence=0.019417475728155338, lift=9.72639011473963), OrderedStatistic(items_base=frozenset({'Pick and Mix Bowls'}), items_add=frozenset({'Jam'}), confidence=0.18181818181818182, lift=9.72639011473963)]),
#  RelationRecord(items=frozenset({'Tartine', 'Jam'}), support=0.0007259528130671506, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jam'}), items_add=frozenset({'Tartine'}), confidence=0.038834951456310676, lift=5.094775774387424), OrderedStatistic(items_base=frozenset({'Tartine'}), items_add=frozenset({'Jam'}), confidence=0.09523809523809523, lift=5.094775774387425)]),
#  RelationRecord(items=frozenset({'Jammie Dodgers', 'Tiffin'}), support=0.001996370235934664, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jammie Dodgers'}), items_add=frozenset({'Tiffin'}), confidence=0.09322033898305085, lift=3.8047708725674827), OrderedStatistic(items_base=frozenset({'Tiffin'}), items_add=frozenset({'Jammie Dodgers'}), confidence=0.08148148148148147, lift=3.8047708725674827)]),
#  RelationRecord(items=frozenset({'Jammie Dodgers', 'Vegan mincepie'}), support=0.0009074410163339383, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jammie Dodgers'}), items_add=frozenset({'Vegan mincepie'}), confidence=0.0423728813559322, lift=4.764787270840539), OrderedStatistic(items_base=frozenset({'Vegan mincepie'}), items_add=frozenset({'Jammie Dodgers'}), confidence=0.1020408163265306, lift=4.764787270840539)]),
#  RelationRecord(items=frozenset({'Pick and Mix Bowls', 'Juice'}), support=0.0007259528130671506, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Juice'}), items_add=frozenset({'Pick and Mix Bowls'}), confidence=0.011627906976744184, lift=5.824524312896405), OrderedStatistic(items_base=frozenset({'Pick and Mix Bowls'}), items_add=frozenset({'Juice'}), confidence=0.36363636363636365, lift=5.824524312896406)]),
#  RelationRecord(items=frozenset({'Tacos/Fajita', 'Juice'}), support=0.000544464609800363, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Juice'}), items_add=frozenset({'Tacos/Fajita'}), confidence=0.00872093023255814, lift=4.368393234672305), OrderedStatistic(items_base=frozenset({'Tacos/Fajita'}), items_add=frozenset({'Juice'}), confidence=0.27272727272727276, lift=4.368393234672305)]),
#  RelationRecord(items=frozenset({'Kids biscuit', 'Muffin'}), support=0.000544464609800363, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Kids biscuit'}), items_add=frozenset({'Muffin'}), confidence=0.30000000000000004, lift=5.101851851851853), OrderedStatistic(items_base=frozenset({'Muffin'}), items_add=frozenset({'Kids biscuit'}), confidence=0.00925925925925926, lift=5.101851851851853)]),
#  RelationRecord(items=frozenset({'Pick and Mix Bowls', 'Mineral water'}), support=0.000544464609800363, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mineral water'}), items_add=frozenset({'Pick and Mix Bowls'}), confidence=0.025862068965517244, lift=12.954545454545457), OrderedStatistic(items_base=frozenset({'Pick and Mix Bowls'}), items_add=frozenset({'Mineral water'}), confidence=0.27272727272727276, lift=12.954545454545457)]),
#  RelationRecord(items=frozenset({'Salad', 'Mineral water'}), support=0.001088929219600726, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mineral water'}), items_add=frozenset({'Salad'}), confidence=0.05172413793103449, lift=3.1318681318681323), OrderedStatistic(items_base=frozenset({'Salad'}), items_add=frozenset({'Mineral water'}), confidence=0.06593406593406594, lift=3.131868131868132)]),
#  RelationRecord(items=frozenset({'Pick and Mix Bowls', 'Tartine'}), support=0.000544464609800363, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Pick and Mix Bowls'}), items_add=frozenset({'Tartine'}), confidence=0.27272727272727276, lift=35.77922077922078), OrderedStatistic(items_base=frozenset({'Tartine'}), items_add=frozenset({'Pick and Mix Bowls'}), confidence=0.07142857142857142, lift=35.77922077922078)]),
#  RelationRecord(items=frozenset({'Tshirt', 'Postcard'}), support=0.001088929219600726, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Postcard'}), items_add=frozenset({'Tshirt'}), confidence=0.8571428571428572, lift=429.3506493506494), OrderedStatistic(items_base=frozenset({'Tshirt'}), items_add=frozenset({'Postcard'}), confidence=0.5454545454545455, lift=429.3506493506494)]),
#  RelationRecord(items=frozenset({'Tea', 'Raspberry shortbread sandwich'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Raspberry shortbread sandwich'}), items_add=frozenset({'Tea'}), confidence=0.6666666666666665, lift=3.2109557109557105), OrderedStatistic(items_base=frozenset({'Tea'}), items_add=frozenset({'Raspberry shortbread sandwich'}), confidence=0.0017482517482517483, lift=3.2109557109557105)]),
#  RelationRecord(items=frozenset({'Salad', 'Spanish Brunch'}), support=0.002177858439201452, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Salad'}), items_add=frozenset({'Spanish Brunch'}), confidence=0.13186813186813187, lift=4.324960753532182), OrderedStatistic(items_base=frozenset({'Spanish Brunch'}), items_add=frozenset({'Salad'}), confidence=0.07142857142857142, lift=4.3249607535321815)]),
#  RelationRecord(items=frozenset({'Smoothies', 'Spanish Brunch'}), support=0.001633393829401089, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Smoothies'}), items_add=frozenset({'Spanish Brunch'}), confidence=0.125, lift=4.0997023809523805), OrderedStatistic(items_base=frozenset({'Spanish Brunch'}), items_add=frozenset({'Smoothies'}), confidence=0.05357142857142857, lift=4.0997023809523805)]),
#  RelationRecord(items=frozenset({'Spanish Brunch', 'The Nomad'}), support=0.001633393829401089, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Spanish Brunch'}), items_add=frozenset({'The Nomad'}), confidence=0.05357142857142857, lift=5.466269841269841), OrderedStatistic(items_base=frozenset({'The Nomad'}), items_add=frozenset({'Spanish Brunch'}), confidence=0.16666666666666666, lift=5.466269841269841)]),
#  RelationRecord(items=frozenset({'Spanish Brunch', 'Truffles'}), support=0.0030852994555353903, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Spanish Brunch'}), items_add=frozenset({'Truffles'}), confidence=0.10119047619047619, lift=3.1860544217687075), OrderedStatistic(items_base=frozenset({'Truffles'}), items_add=frozenset({'Spanish Brunch'}), confidence=0.09714285714285716, lift=3.186054421768708)]),
#  RelationRecord(items=frozenset({'Tacos/Fajita', 'Truffles'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Tacos/Fajita'}), items_add=frozenset({'Truffles'}), confidence=0.18181818181818182, lift=5.724675324675325), OrderedStatistic(items_base=frozenset({'Truffles'}), items_add=frozenset({'Tacos/Fajita'}), confidence=0.011428571428571429, lift=5.724675324675325)]),
#  RelationRecord(items=frozenset({'Victorian Sponge', 'Tea'}), support=0.0007259528130671506, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Tea'}), items_add=frozenset({'Victorian Sponge'}), confidence=0.0034965034965034965, lift=3.2109557109557105), OrderedStatistic(items_base=frozenset({'Victorian Sponge'}), items_add=frozenset({'Tea'}), confidence=0.6666666666666665, lift=3.2109557109557105)]),
#  RelationRecord(items=frozenset({'Tshirt', "Valentine's card"}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Tshirt'}), items_add=frozenset({"Valentine's card"}), confidence=0.18181818181818182, lift=333.93939393939394), OrderedStatistic(items_base=frozenset({"Valentine's card"}), items_add=frozenset({'Tshirt'}), confidence=0.6666666666666665, lift=333.9393939393939)]),
#  RelationRecord(items=frozenset({'Argentina Night', 'Afternoon with the baker', 'Tea'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Afternoon with the baker'}), items_add=frozenset({'Argentina Night', 'Tea'}), confidence=0.16666666666666663, lift=459.1666666666666), OrderedStatistic(items_base=frozenset({'Argentina Night'}), items_add=frozenset({'Afternoon with the baker', 'Tea'}), confidence=0.5, lift=918.3333333333333), OrderedStatistic(items_base=frozenset({'Tea'}), items_add=frozenset({'Argentina Night', 'Afternoon with the baker'}), confidence=0.0017482517482517483, lift=4.816433566433567), OrderedStatistic(items_base=frozenset({'Argentina Night', 'Afternoon with the baker'}), items_add=frozenset({'Tea'}), confidence=1.0, lift=4.816433566433567), OrderedStatistic(items_base=frozenset({'Afternoon with the baker', 'Tea'}), items_add=frozenset({'Argentina Night'}), confidence=0.6666666666666665, lift=918.3333333333331), OrderedStatistic(items_base=frozenset({'Argentina Night', 'Tea'}), items_add=frozenset({'Afternoon with the baker'}), confidence=1.0, lift=459.16666666666663)]),
#  RelationRecord(items=frozenset({'Bread', 'Afternoon with the baker', 'Juice'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Afternoon with the baker'}), items_add=frozenset({'Bread', 'Juice'}), confidence=0.16666666666666663, lift=13.119047619047615), OrderedStatistic(items_base=frozenset({'Juice'}), items_add=frozenset({'Bread', 'Afternoon with the baker'}), confidence=0.005813953488372092, lift=10.678294573643408), OrderedStatistic(items_base=frozenset({'Bread', 'Afternoon with the baker'}), items_add=frozenset({'Juice'}), confidence=0.6666666666666665, lift=10.678294573643408), OrderedStatistic(items_base=frozenset({'Bread', 'Juice'}), items_add=frozenset({'Afternoon with the baker'}), confidence=0.028571428571428567, lift=13.119047619047617)]),
#  RelationRecord(items=frozenset({'Bakewell', 'Bread', 'Alfajores'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Alfajores'}), items_add=frozenset({'Bakewell', 'Bread'}), confidence=0.006269592476489028, lift=3.1404958677685952), OrderedStatistic(items_base=frozenset({'Bakewell', 'Bread'}), items_add=frozenset({'Alfajores'}), confidence=0.18181818181818182, lift=3.1404958677685952)]),
#  RelationRecord(items=frozenset({'Bakewell', 'Tea', 'Alfajores'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Bakewell'}), items_add=frozenset({'Tea', 'Alfajores'}), confidence=0.043478260869565216, lift=3.7432065217391304), OrderedStatistic(items_base=frozenset({'Tea'}), items_add=frozenset({'Bakewell', 'Alfajores'}), confidence=0.0017482517482517483, lift=4.816433566433567), OrderedStatistic(items_base=frozenset({'Bakewell', 'Alfajores'}), items_add=frozenset({'Tea'}), confidence=1.0, lift=4.816433566433567), OrderedStatistic(items_base=frozenset({'Tea', 'Alfajores'}), items_add=frozenset({'Bakewell'}), confidence=0.03125, lift=3.743206521739131)]),
#  RelationRecord(items=frozenset({'Brownie', 'Juice', 'Alfajores'}), support=0.001088929219600726, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Alfajores'}), items_add=frozenset({'Brownie', 'Juice'}), confidence=0.018808777429467086, lift=4.318181818181818), OrderedStatistic(items_base=frozenset({'Brownie'}), items_add=frozenset({'Alfajores', 'Juice'}), confidence=0.01739130434782609, lift=3.3043478260869574), OrderedStatistic(items_base=frozenset({'Juice'}), items_add=frozenset({'Brownie', 'Alfajores'}), confidence=0.01744186046511628, lift=3.5594315245478034), OrderedStatistic(items_base=frozenset({'Brownie', 'Alfajores'}), items_add=frozenset({'Juice'}), confidence=0.22222222222222224, lift=3.559431524547804), OrderedStatistic(items_base=frozenset({'Juice', 'Alfajores'}), items_add=frozenset({'Brownie'}), confidence=0.20689655172413796, lift=3.3043478260869574), OrderedStatistic(items_base=frozenset({'Brownie', 'Juice'}), items_add=frozenset({'Alfajores'}), confidence=0.25, lift=4.318181818181818)]),
#  RelationRecord(items=frozenset({'Chicken Stew', 'Cake', 'Alfajores'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cake'}), items_add=frozenset({'Alfajores', 'Chicken Stew'}), confidence=0.002262443438914027, lift=4.155354449472096), OrderedStatistic(items_base=frozenset({'Chicken Stew', 'Alfajores'}), items_add=frozenset({'Cake'}), confidence=0.6666666666666665, lift=4.155354449472096)]),
#  RelationRecord(items=frozenset({'Mineral water', 'Cake', 'Alfajores'}), support=0.000544464609800363, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Alfajores'}), items_add=frozenset({'Mineral water', 'Cake'}), confidence=0.009404388714733543, lift=3.9860139860139863), OrderedStatistic(items_base=frozenset({'Mineral water'}), items_add=frozenset({'Cake', 'Alfajores'}), confidence=0.025862068965517244, lift=3.653846153846154), OrderedStatistic(items_base=frozenset({'Cake', 'Alfajores'}), items_add=frozenset({'Mineral water'}), confidence=0.07692307692307693, lift=3.653846153846154), OrderedStatistic(items_base=frozenset({'Mineral water', 'Cake'}), items_add=frozenset({'Alfajores'}), confidence=0.23076923076923078, lift=3.9860139860139863)]),
#  RelationRecord(items=frozenset({'Tea', 'Chicken Stew', 'Alfajores'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Tea'}), items_add=frozenset({'Alfajores', 'Chicken Stew'}), confidence=0.0017482517482517483, lift=3.2109557109557105), OrderedStatistic(items_base=frozenset({'Chicken Stew', 'Alfajores'}), items_add=frozenset({'Tea'}), confidence=0.6666666666666665, lift=3.2109557109557105)]),
#  RelationRecord(items=frozenset({'Coke', 'Juice', 'Alfajores'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Juice'}), items_add=frozenset({'Coke', 'Alfajores'}), confidence=0.005813953488372092, lift=5.339147286821704), OrderedStatistic(items_base=frozenset({'Coke', 'Alfajores'}), items_add=frozenset({'Juice'}), confidence=0.33333333333333326, lift=5.339147286821704)]),
#  RelationRecord(items=frozenset({'Coke', 'Pastry', 'Alfajores'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Alfajores'}), items_add=frozenset({'Coke', 'Pastry'}), confidence=0.006269592476489028, lift=4.318181818181818), OrderedStatistic(items_base=frozenset({'Coke', 'Pastry'}), items_add=frozenset({'Alfajores'}), confidence=0.25, lift=4.318181818181818)]),
#  RelationRecord(items=frozenset({'Coke', 'Sandwich', 'Alfajores'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Coke'}), items_add=frozenset({'Sandwich', 'Alfajores'}), confidence=0.014598540145985401, lift=3.2175182481751823), OrderedStatistic(items_base=frozenset({'Sandwich', 'Alfajores'}), items_add=frozenset({'Coke'}), confidence=0.07999999999999999, lift=3.2175182481751823)]),
#  RelationRecord(items=frozenset({'Juice', 'Cookies', 'Alfajores'}), support=0.0018148820326678765, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cookies'}), items_add=frozenset({'Alfajores', 'Juice'}), confidence=0.02127659574468085, lift=4.042553191489362), OrderedStatistic(items_base=frozenset({'Juice'}), items_add=frozenset({'Cookies', 'Alfajores'}), confidence=0.02906976744186046, lift=6.964105156723964), OrderedStatistic(items_base=frozenset({'Cookies', 'Alfajores'}), items_add=frozenset({'Juice'}), confidence=0.4347826086956522, lift=6.9641051567239645), OrderedStatistic(items_base=frozenset({'Juice', 'Alfajores'}), items_add=frozenset({'Cookies'}), confidence=0.3448275862068965, lift=4.042553191489361)]),
#  RelationRecord(items=frozenset({'Mineral water', 'Cookies', 'Alfajores'}), support=0.0007259528130671506, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Alfajores'}), items_add=frozenset({'Mineral water', 'Cookies'}), confidence=0.012539184952978056, lift=5.314685314685314), OrderedStatistic(items_base=frozenset({'Cookies'}), items_add=frozenset({'Mineral water', 'Alfajores'}), confidence=0.00851063829787234, lift=3.907801418439716), OrderedStatistic(items_base=frozenset({'Mineral water'}), items_add=frozenset({'Cookies', 'Alfajores'}), confidence=0.034482758620689655, lift=8.260869565217392), OrderedStatistic(items_base=frozenset({'Cookies', 'Alfajores'}), items_add=frozenset({'Mineral water'}), confidence=0.17391304347826086, lift=8.26086956521739), OrderedStatistic(items_base=frozenset({'Mineral water', 'Alfajores'}), items_add=frozenset({'Cookies'}), confidence=0.33333333333333326, lift=3.9078014184397154), OrderedStatistic(items_base=frozenset({'Mineral water', 'Cookies'}), items_add=frozenset({'Alfajores'}), confidence=0.30769230769230765, lift=5.314685314685314)]),
#  RelationRecord(items=frozenset({'Scandinavian', 'Farm House', 'Alfajores'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Farm House'}), items_add=frozenset({'Alfajores', 'Scandinavian'}), confidence=0.01176470588235294, lift=4.630252100840336), OrderedStatistic(items_base=frozenset({'Scandinavian'}), items_add=frozenset({'Farm House', 'Alfajores'}), confidence=0.012499999999999999, lift=17.21875), OrderedStatistic(items_base=frozenset({'Farm House', 'Alfajores'}), items_add=frozenset({'Scandinavian'}), confidence=0.5, lift=17.21875), OrderedStatistic(items_base=frozenset({'Scandinavian', 'Alfajores'}), items_add=frozenset({'Farm House'}), confidence=0.14285714285714285, lift=4.630252100840336)]),
#  RelationRecord(items=frozenset({'Fudge', 'Medialuna', 'Alfajores'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Alfajores'}), items_add=frozenset({'Fudge', 'Medialuna'}), confidence=0.006269592476489028, lift=4.9350649350649345), OrderedStatistic(items_base=frozenset({'Fudge'}), items_add=frozenset({'Medialuna', 'Alfajores'}), confidence=0.021739130434782608, lift=3.9927536231884058), OrderedStatistic(items_base=frozenset({'Medialuna', 'Alfajores'}), items_add=frozenset({'Fudge'}), confidence=0.06666666666666667, lift=3.992753623188406), OrderedStatistic(items_base=frozenset({'Fudge', 'Medialuna'}), items_add=frozenset({'Alfajores'}), confidence=0.2857142857142857, lift=4.9350649350649345)]),
#  RelationRecord(items=frozenset({'Fudge', 'Sandwich', 'Alfajores'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Fudge'}), items_add=frozenset({'Sandwich', 'Alfajores'}), confidence=0.021739130434782608, lift=4.791304347826086), OrderedStatistic(items_base=frozenset({'Sandwich', 'Alfajores'}), items_add=frozenset({'Fudge'}), confidence=0.07999999999999999, lift=4.791304347826086)]),
#  RelationRecord(items=frozenset({'Hot chocolate', 'Mineral water', 'Alfajores'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Alfajores'}), items_add=frozenset({'Hot chocolate', 'Mineral water'}), confidence=0.006269592476489028, lift=3.8383838383838382), OrderedStatistic(items_base=frozenset({'Hot chocolate', 'Mineral water'}), items_add=frozenset({'Alfajores'}), confidence=0.2222222222222222, lift=3.8383838383838382)]),
#  RelationRecord(items=frozenset({'Hot chocolate', 'Spanish Brunch', 'Alfajores'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Alfajores'}), items_add=frozenset({'Hot chocolate', 'Spanish Brunch'}), confidence=0.006269592476489028, lift=4.318181818181818), OrderedStatistic(items_base=frozenset({'Hot chocolate', 'Spanish Brunch'}), items_add=frozenset({'Alfajores'}), confidence=0.25, lift=4.318181818181818)]),
#  RelationRecord(items=frozenset({'Hot chocolate', 'Toast', 'Alfajores'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Hot chocolate'}), items_add=frozenset({'Toast', 'Alfajores'}), confidence=0.004140786749482401, lift=4.563146997929606), OrderedStatistic(items_base=frozenset({'Toast', 'Alfajores'}), items_add=frozenset({'Hot chocolate'}), confidence=0.39999999999999997, lift=4.563146997929606)]),
#  RelationRecord(items=frozenset({'Medialuna', 'Jam', 'Alfajores'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Alfajores'}), items_add=frozenset({'Medialuna', 'Jam'}), confidence=0.006269592476489028, lift=6.909090909090909), OrderedStatistic(items_base=frozenset({'Jam'}), items_add=frozenset({'Medialuna', 'Alfajores'}), confidence=0.019417475728155338, lift=3.5663430420711975), OrderedStatistic(items_base=frozenset({'Medialuna'}), items_add=frozenset({'Jam', 'Alfajores'}), confidence=0.0037878787878787876, lift=10.43560606060606), OrderedStatistic(items_base=frozenset({'Jam', 'Alfajores'}), items_add=frozenset({'Medialuna'}), confidence=1.0, lift=10.43560606060606), OrderedStatistic(items_base=frozenset({'Medialuna', 'Alfajores'}), items_add=frozenset({'Jam'}), confidence=0.06666666666666667, lift=3.5663430420711975), OrderedStatistic(items_base=frozenset({'Medialuna', 'Jam'}), items_add=frozenset({'Alfajores'}), confidence=0.39999999999999997, lift=6.909090909090908)]),
#  RelationRecord(items=frozenset({'Tea', 'Jam', 'Alfajores'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Tea'}), items_add=frozenset({'Jam', 'Alfajores'}), confidence=0.0017482517482517483, lift=4.816433566433567), OrderedStatistic(items_base=frozenset({'Jam', 'Alfajores'}), items_add=frozenset({'Tea'}), confidence=1.0, lift=4.816433566433567)]),
#  RelationRecord(items=frozenset({'Mineral water', 'Juice', 'Alfajores'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mineral water'}), items_add=frozenset({'Alfajores', 'Juice'}), confidence=0.017241379310344827, lift=3.2758620689655173), OrderedStatistic(items_base=frozenset({'Juice', 'Alfajores'}), items_add=frozenset({'Mineral water'}), confidence=0.06896551724137931, lift=3.2758620689655173)]),
#  RelationRecord(items=frozenset({'Sandwich', 'Juice', 'Alfajores'}), support=0.0009074410163339383, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Juice'}), items_add=frozenset({'Sandwich', 'Alfajores'}), confidence=0.01453488372093023, lift=3.2034883720930227), OrderedStatistic(items_base=frozenset({'Sandwich', 'Alfajores'}), items_add=frozenset({'Juice'}), confidence=0.19999999999999998, lift=3.2034883720930227)]),
#  RelationRecord(items=frozenset({'Spanish Brunch', 'Juice', 'Alfajores'}), support=0.000544464609800363, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Juice'}), items_add=frozenset({'Spanish Brunch', 'Alfajores'}), confidence=0.00872093023255814, lift=4.805232558139535), OrderedStatistic(items_base=frozenset({'Spanish Brunch'}), items_add=frozenset({'Alfajores', 'Juice'}), confidence=0.017857142857142856, lift=3.392857142857143), OrderedStatistic(items_base=frozenset({'Juice', 'Alfajores'}), items_add=frozenset({'Spanish Brunch'}), confidence=0.10344827586206898, lift=3.3928571428571432), OrderedStatistic(items_base=frozenset({'Spanish Brunch', 'Alfajores'}), items_add=frozenset({'Juice'}), confidence=0.30000000000000004, lift=4.805232558139536)]),
#  RelationRecord(items=frozenset({'Toast', 'Juice', 'Alfajores'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Juice'}), items_add=frozenset({'Toast', 'Alfajores'}), confidence=0.005813953488372092, lift=6.4069767441860455), OrderedStatistic(items_base=frozenset({'Toast', 'Alfajores'}), items_add=frozenset({'Juice'}), confidence=0.39999999999999997, lift=6.4069767441860455)]),
# ...
#  RelationRecord(items=frozenset({'Spanish Brunch', 'Coffee', 'Salad', 'Extra Salami or Feta', 'Juice'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Extra Salami or Feta'}), items_add=frozenset({'Salad', 'Spanish Brunch', 'Coffee', 'Juice'}), confidence=0.05405405405405405, lift=148.9189189189189), OrderedStatistic(items_base=frozenset({'Juice'}), items_add=frozenset({'Salad', 'Extra Salami or Feta', 'Spanish Brunch', 'Coffee'}), confidence=0.005813953488372092, lift=10.678294573643408), OrderedStatistic(items_base=frozenset({'Salad'}), items_add=frozenset({'Extra Salami or Feta', 'Spanish Brunch', 'Coffee', 'Juice'}), confidence=0.021978021978021976, lift=60.54945054945055), OrderedStatistic(items_base=frozenset({'Spanish Brunch'}), items_add=frozenset({'Salad', 'Extra Salami or Feta', 'Coffee', 'Juice'}), confidence=0.011904761904761904, lift=21.865079365079364), OrderedStatistic(items_base=frozenset({'Extra Salami or Feta', 'Coffee'}), items_add=frozenset({'Salad', 'Spanish Brunch', 'Juice'}), confidence=0.06451612903225806, lift=177.74193548387098), OrderedStatistic(items_base=frozenset({'Coffee', 'Juice'}), items_add=frozenset({'Salad', 'Extra Salami or Feta', 'Spanish Brunch'}), confidence=0.010309278350515464, lift=18.934707903780065), OrderedStatistic(items_base=frozenset({'Salad', 'Coffee'}), items_add=frozenset({'Extra Salami or Feta', 'Spanish Brunch', 'Juice'}), confidence=0.03225806451612903, lift=88.87096774193549), OrderedStatistic(items_base=frozenset({'Spanish Brunch', 'Coffee'}), items_add=frozenset({'Salad', 'Extra Salami or Feta', 'Juice'}), confidence=0.019417475728155338, lift=35.66343042071197), OrderedStatistic(items_base=frozenset({'Extra Salami or Feta', 'Juice'}), items_add=frozenset({'Salad', 'Spanish Brunch', 'Coffee'}), confidence=0.5, lift=344.375), OrderedStatistic(items_base=frozenset({'Salad', 'Extra Salami or Feta'}), items_add=frozenset({'Spanish Brunch', 'Coffee', 'Juice'}), confidence=0.125, lift=36.25), OrderedStatistic(items_base=frozenset({'Extra Salami or Feta', 'Spanish Brunch'}), items_add=frozenset({'Salad', 'Coffee', 'Juice'}), confidence=0.25, lift=229.58333333333331), OrderedStatistic(items_base=frozenset({'Salad', 'Juice'}), items_add=frozenset({'Extra Salami or Feta', 'Spanish Brunch', 'Coffee'}), confidence=0.19999999999999998, lift=183.66666666666663), OrderedStatistic(items_base=frozenset({'Spanish Brunch', 'Juice'}), items_add=frozenset({'Salad', 'Extra Salami or Feta', 'Coffee'}), confidence=0.07692307692307691, lift=30.27472527472527), OrderedStatistic(items_base=frozenset({'Salad', 'Spanish Brunch'}), items_add=frozenset({'Extra Salami or Feta', 'Coffee', 'Juice'}), confidence=0.16666666666666663, lift=229.5833333333333), OrderedStatistic(items_base=frozenset({'Extra Salami or Feta', 'Coffee', 'Juice'}), items_add=frozenset({'Salad', 'Spanish Brunch'}), confidence=0.5, lift=229.58333333333331), OrderedStatistic(items_base=frozenset({'Salad', 'Extra Salami or Feta', 'Coffee'}), items_add=frozenset({'Spanish Brunch', 'Juice'}), confidence=0.14285714285714285, lift=30.274725274725274), OrderedStatistic(items_base=frozenset({'Extra Salami or Feta', 'Spanish Brunch', 'Coffee'}), items_add=frozenset({'Salad', 'Juice'}), confidence=0.33333333333333326, lift=183.66666666666663), OrderedStatistic(items_base=frozenset({'Salad', 'Coffee', 'Juice'}), items_add=frozenset({'Extra Salami or Feta', 'Spanish Brunch'}), confidence=0.33333333333333326, lift=229.5833333333333), OrderedStatistic(items_base=frozenset({'Spanish Brunch', 'Coffee', 'Juice'}), items_add=frozenset({'Salad', 'Extra Salami or Feta'}), confidence=0.10526315789473684, lift=36.25), OrderedStatistic(items_base=frozenset({'Salad', 'Spanish Brunch', 'Coffee'}), items_add=frozenset({'Extra Salami or Feta', 'Juice'}), confidence=0.25, lift=344.375), OrderedStatistic(items_base=frozenset({'Salad', 'Extra Salami or Feta', 'Juice'}), items_add=frozenset({'Spanish Brunch', 'Coffee' ...
#  RelationRecord(items=frozenset({'Pastry', 'Coffee', 'Farm House', 'Medialuna', 'Hot chocolate'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Farm House'}), items_add=frozenset({'Hot chocolate', 'Pastry', 'Medialuna', 'Coffee'}), confidence=0.01176470588235294, lift=10.803921568627448), OrderedStatistic(items_base=frozenset({'Hot chocolate'}), items_add=frozenset({'Pastry', 'Farm House', 'Coffee', 'Medialuna'}), confidence=0.004140786749482401, lift=4.563146997929606), OrderedStatistic(items_base=frozenset({'Medialuna'}), items_add=frozenset({'Hot chocolate', 'Pastry', 'Farm House', 'Coffee'}), confidence=0.0037878787878787876, lift=10.43560606060606), OrderedStatistic(items_base=frozenset({'Pastry'}), items_add=frozenset({'Hot chocolate', 'Farm House', 'Coffee', 'Medialuna'}), confidence=0.0026666666666666666, lift=7.346666666666667), OrderedStatistic(items_base=frozenset({'Farm House', 'Coffee'}), items_add=frozenset({'Hot chocolate', 'Pastry', 'Medialuna'}), confidence=0.031746031746031744, lift=24.988662131519273), OrderedStatistic(items_base=frozenset({'Hot chocolate', 'Coffee'}), items_add=frozenset({'Pastry', 'Farm House', 'Medialuna'}), confidence=0.007142857142857142, lift=4.919642857142857), OrderedStatistic(items_base=frozenset({'Medialuna', 'Coffee'}), items_add=frozenset({'Hot chocolate', 'Pastry', 'Farm House'}), confidence=0.006006006006006005, lift=16.546546546546544), OrderedStatistic(items_base=frozenset({'Pastry', 'Coffee'}), items_add=frozenset({'Hot chocolate', 'Farm House', 'Medialuna'}), confidence=0.0044444444444444444, lift=12.244444444444445), OrderedStatistic(items_base=frozenset({'Hot chocolate', 'Farm House'}), items_add=frozenset({'Pastry', 'Medialuna', 'Coffee'}), confidence=0.25, lift=29.945652173913047), OrderedStatistic(items_base=frozenset({'Farm House', 'Medialuna'}), items_add=frozenset({'Hot chocolate', 'Pastry', 'Coffee'}), confidence=0.09090909090909091, lift=13.914141414141413), OrderedStatistic(items_base=frozenset({'Pastry', 'Farm House'}), items_add=frozenset({'Hot chocolate', 'Medialuna', 'Coffee'}), confidence=0.07692307692307691, lift=14.615384615384613), OrderedStatistic(items_base=frozenset({'Hot chocolate', 'Medialuna'}), items_add=frozenset({'Pastry', 'Farm House', 'Coffee'}), confidence=0.044444444444444446, lift=24.48888888888889), OrderedStatistic(items_base=frozenset({'Hot chocolate', 'Pastry'}), items_add=frozenset({'Farm House', 'Coffee', 'Medialuna'}), confidence=0.037037037037037035, lift=17.00617283950617), OrderedStatistic(items_base=frozenset({'Pastry', 'Medialuna'}), items_add=frozenset({'Hot chocolate', 'Farm House', 'Coffee'}), confidence=0.022988505747126433, lift=18.09523809523809), OrderedStatistic(items_base=frozenset({'Hot chocolate', 'Farm House', 'Coffee'}), items_add=frozenset({'Pastry', 'Medialuna'}), confidence=0.2857142857142857, lift=18.095238095238095), OrderedStatistic(items_base=frozenset({'Farm House', 'Coffee', 'Medialuna'}), items_add=frozenset({'Hot chocolate', 'Pastry'}), confidence=0.16666666666666663, lift=17.006172839506167), OrderedStatistic(items_base=frozenset({'Pastry', 'Farm House', 'Coffee'}), items_add=frozenset({'Hot chocolate', 'Medialuna'}), confidence=0.19999999999999998, lift=24.48888888888889), OrderedStatistic(items_base=frozenset({'Hot chocolate', 'Medialuna', 'Coffee'}), items_add=frozenset({'Pastry', 'Farm House'}), confidence=0.06896551724137931, lift=14.615384615384615), OrderedStatistic(items_base=frozenset({'Hot chocolate', 'Pastry', 'Coffee'}), items_add=frozenset({'Farm House', 'Medialuna'}), confidence=0.05555555555555555, lift=13.914141414141415), OrderedStatistic(items_base=frozenset({'Pastry', 'Medialuna', 'Coffee'}), items_add=frozenset({'Hot chocolate', 'Farm House'}), confidence=0.043478260869565216, lift=29.945652173913043), OrderedStatistic(items_base=frozenset({'Hot chocolate', 'Farm House', 'Medialuna'}), items_add=frozenset({'Pastry', 'Coffee'}), confidence=1 ...
#  RelationRecord(items=frozenset({'Coffee', 'Cake', 'Soup', 'Cookies', 'Sandwich', 'Tea'}), support=0.0003629764065335753, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cake'}), items_add=frozenset({'Coffee', 'Soup', 'Cookies', 'Sandwich', 'Tea'}), confidence=0.002262443438914027, lift=6.233031674208145), OrderedStatistic(items_base=frozenset({'Cookies'}), items_add=frozenset({'Cake', 'Coffee', 'Soup', 'Sandwich', 'Tea'}), confidence=0.00425531914893617, lift=5.861702127659575), OrderedStatistic(items_base=frozenset({'Sandwich'}), items_add=frozenset({'Cake', 'Coffee', 'Soup', 'Cookies', 'Tea'}), confidence=0.003262642740619902, lift=8.98858075040783), OrderedStatistic(items_base=frozenset({'Soup'}), items_add=frozenset({'Cake', 'Coffee', 'Cookies', 'Sandwich', 'Tea'}), confidence=0.006993006993006993, lift=12.843822843822842), OrderedStatistic(items_base=frozenset({'Tea'}), items_add=frozenset({'Cake', 'Coffee', 'Soup', 'Cookies', 'Sandwich'}), confidence=0.0017482517482517483, lift=4.816433566433567), OrderedStatistic(items_base=frozenset({'Coffee', 'Cake'}), items_add=frozenset({'Sandwich', 'Soup', 'Tea', 'Cookies'}), confidence=0.003861003861003861, lift=10.637065637065637), OrderedStatistic(items_base=frozenset({'Cookies', 'Cake'}), items_add=frozenset({'Sandwich', 'Soup', 'Tea', 'Coffee'}), confidence=0.02898550724637681, lift=22.815734989648032), OrderedStatistic(items_base=frozenset({'Sandwich', 'Cake'}), items_add=frozenset({'Cookies', 'Soup', 'Tea', 'Coffee'}), confidence=0.030769230769230764, lift=84.76923076923076), OrderedStatistic(items_base=frozenset({'Soup', 'Cake'}), items_add=frozenset({'Cookies', 'Sandwich', 'Tea', 'Coffee'}), confidence=0.047619047619047616, lift=43.73015873015873), OrderedStatistic(items_base=frozenset({'Tea', 'Cake'}), items_add=frozenset({'Cookies', 'Sandwich', 'Soup', 'Coffee'}), confidence=0.008888888888888889, lift=24.48888888888889), OrderedStatistic(items_base=frozenset({'Cookies', 'Coffee'}), items_add=frozenset({'Sandwich', 'Soup', 'Tea', 'Cake'}), confidence=0.00749063670411985, lift=10.318352059925095), OrderedStatistic(items_base=frozenset({'Sandwich', 'Coffee'}), items_add=frozenset({'Cookies', 'Soup', 'Tea', 'Cake'}), confidence=0.005524861878453038, lift=15.22099447513812), OrderedStatistic(items_base=frozenset({'Soup', 'Coffee'}), items_add=frozenset({'Cookies', 'Sandwich', 'Tea', 'Cake'}), confidence=0.013333333333333332, lift=24.488888888888884), OrderedStatistic(items_base=frozenset({'Tea', 'Coffee'}), items_add=frozenset({'Cookies', 'Sandwich', 'Soup', 'Cake'}), confidence=0.004246284501061571, lift=11.69851380042463), OrderedStatistic(items_base=frozenset({'Sandwich', 'Cookies'}), items_add=frozenset({'Cake', 'Tea', 'Coffee', 'Soup'}), confidence=0.07407407407407407, lift=51.01851851851852), OrderedStatistic(items_base=frozenset({'Soup', 'Cookies'}), items_add=frozenset({'Sandwich', 'Cake', 'Tea', 'Coffee'}), confidence=0.16666666666666663, lift=91.83333333333331), OrderedStatistic(items_base=frozenset({'Tea', 'Cookies'}), items_add=frozenset({'Sandwich', 'Cake', 'Coffee', 'Soup'}), confidence=0.02150537634408602, lift=13.166069295101552), OrderedStatistic(items_base=frozenset({'Sandwich', 'Soup'}), items_add=frozenset({'Cookies', 'Cake', 'Tea', 'Coffee'}), confidence=0.03846153846153846, lift=30.27472527472527), OrderedStatistic(items_base=frozenset({'Sandwich', 'Tea'}), items_add=frozenset({'Cookies', 'Cake', 'Coffee', 'Soup'}), confidence=0.014705882352941175, lift=40.51470588235294), OrderedStatistic(items_base=frozenset({'Soup', 'Tea'}), items_add=frozenset({'Cookies', 'Sandwich', 'Cake', 'Coffee'}), confidence=0.02325581395348837, lift=42.71317829457363), OrderedStatistic(items_base=frozenset({'Cookies', 'Coffee', 'Cake'}), items_add=frozenset({'Soup', 'Tea', 'Sandwich'}), confidence=0.049999999999999996, lift=18.366666666666667), OrderedStatistic(items_base=frozenset({'Sandwich', 'Coffee', 'Cake'}), items_add=frozenset({'Soup', 'Tea', 'Cookies'}), c ...

# %%
for item in association_results:
    print (item[0])
# Out:
# frozenset({'Argentina Night', 'Afternoon with the baker'})
# frozenset({'Afternoon with the baker', 'Spanish Brunch'})
# frozenset({'Crepes', 'Alfajores'})
# frozenset({'Dulce de Leche', 'Alfajores'})
# frozenset({'Frittata', 'Art Tray'})
# frozenset({'Hack the stack', 'Art Tray'})
# frozenset({'Art Tray', 'Hearty & Seasonal'})
# frozenset({'Juice', 'Art Tray'})
# frozenset({'Art Tray', 'My-5 Fruit Shoot'})
# frozenset({'Salad', 'Art Tray'})
# frozenset({'Soup', 'Art Tray'})
# frozenset({'Spanish Brunch', 'Art Tray'})
# frozenset({'Baguette', 'Scandinavian'})
# frozenset({'Cookies', 'Bare Popcorn'})
# frozenset({'Juice', 'Bare Popcorn'})
# frozenset({'Hot chocolate', 'Basket'})
# frozenset({'Brownie', 'My-5 Fruit Shoot'})
# frozenset({'Coke', 'Chicken Stew'})
# frozenset({'Granola', 'Chicken Stew'})
# frozenset({'Spanish Brunch', 'Chicken Stew'})
# frozenset({'Coke', 'Chocolates'})
# frozenset({'Hot chocolate', 'Chocolates'})
# frozenset({'Chocolates', 'Juice'})
# frozenset({'Christmas common', 'Jam'})
# frozenset({'Coke', 'Crisps'})
# frozenset({'Coke', 'Mineral water'})
# frozenset({'Salad', 'Coke'})
# frozenset({'Coke', 'Sandwich'})
# frozenset({'Tacos/Fajita', 'Coke'})
# frozenset({'Vegan Feast', 'Cookies'})
# frozenset({'Medialuna', 'Crepes'})
# frozenset({'Crisps', 'Frittata'})
# frozenset({'Crisps', 'Juice'})
# frozenset({'Mineral water', 'Crisps'})
# frozenset({'Sandwich', 'Crisps'})
# frozenset({'Crisps', 'Truffles'})
# frozenset({'Drinking chocolate spoons ', 'Juice'})
# frozenset({'Drinking chocolate spoons ', 'Mineral water'})
# frozenset({'Extra Salami or Feta', 'Duck egg'})
# frozenset({'Duck egg', 'Spanish Brunch'})
# frozenset({'Duck egg', 'Truffles'})
# frozenset({'Fudge', 'Dulce de Leche'})
# frozenset({'Fudge', 'Eggs'})
# frozenset({'Scandinavian', 'Eggs'})
# frozenset({'Jam', "Ella's Kitchen Pouches"})
# frozenset({"Ella's Kitchen Pouches", 'Juice'})
# frozenset({'Salad', 'Extra Salami or Feta'})
# frozenset({'Extra Salami or Feta', 'Spanish Brunch'})
# frozenset({'Farm House', 'Focaccia'})
# frozenset({'Farm House', 'Scandinavian'})
# frozenset({'Fudge', 'Focaccia'})
# frozenset({'Focaccia', 'Scandinavian'})
# frozenset({'Mineral water', 'Frittata'})
# frozenset({'Fudge', 'Jam'})
# frozenset({'Half slice Monster ', 'Juice'})
# frozenset({'Mighty Protein', 'Hearty & Seasonal'})
# frozenset({'Mineral water', 'Hearty & Seasonal'})
# frozenset({'Pick and Mix Bowls', 'Hearty & Seasonal'})
# frozenset({'Smoothies', 'Hearty & Seasonal'})
# frozenset({'Pick and Mix Bowls', 'Jam'})
# frozenset({'Tartine', 'Jam'})
# frozenset({'Jammie Dodgers', 'Tiffin'})
# frozenset({'Jammie Dodgers', 'Vegan mincepie'})
# frozenset({'Pick and Mix Bowls', 'Juice'})
# frozenset({'Tacos/Fajita', 'Juice'})
# frozenset({'Kids biscuit', 'Muffin'})
# frozenset({'Pick and Mix Bowls', 'Mineral water'})
# frozenset({'Salad', 'Mineral water'})
# frozenset({'Pick and Mix Bowls', 'Tartine'})
# frozenset({'Tshirt', 'Postcard'})
# frozenset({'Tea', 'Raspberry shortbread sandwich'})
# frozenset({'Salad', 'Spanish Brunch'})
# frozenset({'Smoothies', 'Spanish Brunch'})
# frozenset({'Spanish Brunch', 'The Nomad'})
# frozenset({'Spanish Brunch', 'Truffles'})
# frozenset({'Tacos/Fajita', 'Truffles'})
# frozenset({'Victorian Sponge', 'Tea'})
# frozenset({'Tshirt', "Valentine's card"})
# frozenset({'Argentina Night', 'Afternoon with the baker', 'Tea'})
# frozenset({'Bread', 'Afternoon with the baker', 'Juice'})
# frozenset({'Bakewell', 'Bread', 'Alfajores'})
# frozenset({'Bakewell', 'Tea', 'Alfajores'})
# frozenset({'Brownie', 'Juice', 'Alfajores'})
# frozenset({'Chicken Stew', 'Cake', 'Alfajores'})
# frozenset({'Mineral water', 'Cake', 'Alfajores'})
# frozenset({'Tea', 'Chicken Stew', 'Alfajores'})
# frozenset({'Coke', 'Juice', 'Alfajores'})
# frozenset({'Coke', 'Pastry', 'Alfajores'})
# frozenset({'Coke', 'Sandwich', 'Alfajores'})
# frozenset({'Juice', 'Cookies', 'Alfajores'})
# frozenset({'Mineral water', 'Cookies', 'Alfajores'})
# frozenset({'Scandinavian', 'Farm House', 'Alfajores'})
# frozenset({'Fudge', 'Medialuna', 'Alfajores'})
# frozenset({'Fudge', 'Sandwich', 'Alfajores'})
# frozenset({'Hot chocolate', 'Mineral water', 'Alfajores'})
# frozenset({'Hot chocolate', 'Spanish Brunch', 'Alfajores'})
# frozenset({'Hot chocolate', 'Toast', 'Alfajores'})
# frozenset({'Medialuna', 'Jam', 'Alfajores'})
# frozenset({'Tea', 'Jam', 'Alfajores'})
# frozenset({'Mineral water', 'Juice', 'Alfajores'})
# frozenset({'Sandwich', 'Juice', 'Alfajores'})
# frozenset({'Spanish Brunch', 'Juice', 'Alfajores'})
# frozenset({'Toast', 'Juice', 'Alfajores'})
# frozenset({'Truffles', 'Juice', 'Alfajores'})
# frozenset({'Sandwich', 'Mineral water', 'Alfajores'})
# frozenset({'Tea', 'Mineral water', 'Alfajores'})
# frozenset({'Tiffin', 'Muffin', 'Alfajores'})
# frozenset({'Tiffin', 'Pastry', 'Alfajores'})
# frozenset({'Salad', 'Sandwich', 'Alfajores'})
# frozenset({'Scone', 'Spanish Brunch', 'Alfajores'})
# frozenset({'Spanish Brunch', 'Tea', 'Alfajores'})
# frozenset({'Sandwich', 'Brownie', 'Art Tray'})
# frozenset({'Juice', 'Cake', 'Art Tray'})
# frozenset({'Chicken Stew', 'Coffee', 'Art Tray'})
# frozenset({'Coffee', 'Art Tray', 'Hearty & Seasonal'})
# frozenset({'Salad', 'Coffee', 'Art Tray'})
# frozenset({'Soup', 'Coffee', 'Art Tray'})
# frozenset({'Spanish Brunch', 'Coffee', 'Art Tray'})
# frozenset({'Truffles', 'Coffee', 'Art Tray'})
# frozenset({'Juice', 'Cookies', 'Art Tray'})
# frozenset({'Hot chocolate', 'Juice', 'Art Tray'})
# frozenset({'Hot chocolate', 'Sandwich', 'Art Tray'})
# frozenset({'Hot chocolate', 'Tea', 'Art Tray'})
# frozenset({'Muffin', 'Juice', 'Art Tray'})
# frozenset({'Spanish Brunch', 'Juice', 'Art Tray'})
# frozenset({'Toast', 'Juice', 'Art Tray'})
# frozenset({'Baguette', 'Cake', 'Scandinavian'})
# frozenset({'Bakewell', 'Bread', 'Toast'})
# frozenset({'Bakewell', 'Cake', 'Cookies'})
# frozenset({'Bakewell', 'Coffee', 'Jammie Dodgers'})
# frozenset({'Bakewell', 'Sandwich', 'Cookies'})
# frozenset({'Bakewell', 'Sandwich', 'Juice'})
# frozenset({'Bakewell', 'Tea', 'Juice'})
# frozenset({'Cookies', 'Coffee', 'Bare Popcorn'})
# frozenset({'Juice', 'Coffee', 'Bare Popcorn'})
# frozenset({'Hot chocolate', 'Basket', 'Coffee'})
# frozenset({'Bread', 'Cake', 'Eggs'})
# frozenset({'Jammie Dodgers', 'Bread', 'Cake'})
# frozenset({'Bread', 'Lemon and coconut', 'Cake'})
# frozenset({'Bread', 'Coke', 'Chicken Stew'})
# frozenset({'Bread', 'Soup', 'Chicken Stew'})
# frozenset({'Tiffin', 'Bread', 'Chicken Stew'})
# frozenset({'Hot chocolate', 'Bread', 'Chocolates'})
# frozenset({'Christmas common', 'Bread', 'Jam'})
# frozenset({'Bread', 'Coke', 'Farm House'})
# frozenset({'Bread', 'Coke', 'Mineral water'})
# frozenset({'Bread', 'Coke', 'Sandwich'})
# frozenset({'Bread', 'Coke', 'Soup'})
# frozenset({'Bread', 'Coke', 'Truffles'})
# frozenset({'Bread', 'Crisps', 'Juice'})
# frozenset({'Bread', 'Crisps', 'Truffles'})
# frozenset({'Bread', 'Duck egg', 'Tea'})
# frozenset({'Bread', 'Juice', 'Eggs'})
# frozenset({'Bread', 'Medialuna', 'Eggs'})
# frozenset({'Bread', "Ella's Kitchen Pouches", 'Muffin'})
# frozenset({'Salad', 'Bread', 'Extra Salami or Feta'})
# frozenset({'Bread', 'Extra Salami or Feta', 'Scandinavian'})
# frozenset({'Bread', 'Farm House', 'Jam'})
# frozenset({'Bread', 'Mineral water', 'Frittata'})
# frozenset({'Salad', 'Bread', 'Frittata'})
# frozenset({'Bread', 'Jam', 'Fudge'})
# frozenset({'Bread', 'Mineral water', 'Hearty & Seasonal'})
# frozenset({'Salad', 'Bread', 'Jam'})
# frozenset({'Jammie Dodgers', 'Bread', 'Juice'})
# frozenset({'Jammie Dodgers', 'Bread', 'Tiffin'})
# frozenset({'Salad', 'Bread', 'Mineral water'})
# frozenset({'Bread', 'Spanish Brunch', 'Mineral water'})
# frozenset({'Bread', 'Mineral water', 'Truffles'})
# frozenset({'Bread', 'Muffin', 'My-5 Fruit Shoot'})
# frozenset({'Salad', 'Bread', 'Scandinavian'})
# frozenset({'Salad', 'Bread', 'Soup'})
# frozenset({'Salad', 'Bread', 'Spanish Brunch'})
# frozenset({'Salad', 'Bread', 'Truffles'})
# frozenset({'Bread', 'Smoothies', 'Spanish Brunch'})
# frozenset({'Tacos/Fajita', 'Bread', 'Truffles'})
# frozenset({'Tiffin', 'Bread', 'The Nomad'})
# frozenset({'Brownie', 'Medialuna', 'Chicken Stew'})
# frozenset({'Brownie', 'Coffee', 'My-5 Fruit Shoot'})
# frozenset({'Mineral water', 'Coke', 'Brownie'})
# frozenset({'Scone', 'Coke', 'Brownie'})
# frozenset({'Coke', 'Brownie', 'Truffles'})
# frozenset({'Brownie', 'Farm House', 'Juice'})
# frozenset({'Hot chocolate', 'Brownie', 'Hearty & Seasonal'})
# frozenset({'Sandwich', 'Brownie', 'Hearty & Seasonal'})
# frozenset({'Scone', 'Brownie', 'Juice'})
# frozenset({'Brownie', 'Truffles', 'Medialuna'})
# frozenset({'Spanish Brunch', 'Brownie', 'Truffles'})
# frozenset({'Tea', 'Brownie', 'Toast'})
# frozenset({'Juice', 'Cake', 'Chicken Stew'})
# frozenset({'Salad', 'Cake', 'Chicken Stew'})
# frozenset({'Sandwich', 'Cake', 'Chicken Stew'})
# frozenset({'Soup', 'Cake', 'Chicken Stew'})
# frozenset({'Spanish Brunch', 'Cake', 'Chicken Stew'})
# frozenset({'Truffles', 'Cake', 'Chicken Stew'})
# frozenset({'Dulce de Leche', 'Coffee', 'Cake'})
# frozenset({'Duck egg', 'Cake', 'Spanish Brunch'})
# frozenset({'Juice', 'Cake', 'Eggs'})
# frozenset({'Hot chocolate', 'Extra Salami or Feta', 'Cake'})
# frozenset({'Salad', 'Extra Salami or Feta', 'Cake'})
# frozenset({'Extra Salami or Feta', 'Toast', 'Cake'})
# frozenset({'Farm House', 'Cake', 'Scandinavian'})
# frozenset({'Sandwich', 'Granola', 'Cake'})
# frozenset({'Hot chocolate', 'Salad', 'Cake'})
# frozenset({'Jammie Dodgers', 'Cake', 'Juice'})
# frozenset({'Jammie Dodgers', 'Spanish Brunch', 'Cake'})
# frozenset({'Jammie Dodgers', 'Tiffin', 'Cake'})
# frozenset({'Jammie Dodgers', 'Truffles', 'Cake'})
# frozenset({'Jammie Dodgers', 'Vegan mincepie', 'Cake'})
# frozenset({'Spanish Brunch', 'Medialuna', 'Cake'})
# frozenset({'Pastry', 'Cake', 'Spanish Brunch'})
# frozenset({'Salad', 'Spanish Brunch', 'Cake'})
# frozenset({'Salad', 'Truffles', 'Cake'})
# frozenset({'Sandwich', 'Cake', 'Smoothies'})
# frozenset({'Sandwich', 'Cake', 'Soup'})
# frozenset({'Scone', 'Cake', 'Scandinavian'})
# frozenset({'Smoothies', 'Cake', 'Soup'})
# frozenset({'Smoothies', 'Cake', 'Spanish Brunch'})
# frozenset({'Spanish Brunch', 'The Nomad', 'Cake'})
# frozenset({'Spanish Brunch', 'Toast', 'Cake'})
# frozenset({'Spanish Brunch', 'Cake', 'Truffles'})
# frozenset({'Coke', 'Coffee', 'Chicken Stew'})
# frozenset({'Extra Salami or Feta', 'Coffee', 'Chicken Stew'})
# frozenset({'Salad', 'Coffee', 'Chicken Stew'})
# frozenset({'The Nomad', 'Coffee', 'Chicken Stew'})
# frozenset({'Truffles', 'Coffee', 'Chicken Stew'})
# frozenset({'Coke', 'Juice', 'Chicken Stew'})
# frozenset({'Coke', 'Sandwich', 'Chicken Stew'})
# frozenset({'Tiffin', 'Coke', 'Chicken Stew'})
# frozenset({'Coke', 'Truffles', 'Chicken Stew'})
# frozenset({'Hot chocolate', 'Toast', 'Chicken Stew'})
# frozenset({'Jammie Dodgers', 'Tea', 'Chicken Stew'})
# frozenset({'Sandwich', 'Juice', 'Chicken Stew'})
# frozenset({'Spanish Brunch', 'Juice', 'Chicken Stew'})
# frozenset({'Truffles', 'Juice', 'Chicken Stew'})
# frozenset({'Sandwich', 'Medialuna', 'Chicken Stew'})
# frozenset({'Spanish Brunch', 'Medialuna', 'Chicken Stew'})
# frozenset({'Pastry', 'Soup', 'Chicken Stew'})
# frozenset({'Salad', 'Truffles', 'Chicken Stew'})
# frozenset({'Sandwich', 'Spanish Brunch', 'Chicken Stew'})
# frozenset({'Sandwich', 'Truffles', 'Chicken Stew'})
# frozenset({'Soup', 'Tea', 'Chicken Stew'})
# frozenset({'Spanish Brunch', 'Tea', 'Chicken Stew'})
# frozenset({'Tiffin', 'Tea', 'Chicken Stew'})
# frozenset({'Coke', 'Chocolates', 'Coffee'})
# frozenset({'Cookies', 'Chocolates', 'Coffee'})
# frozenset({'Hot chocolate', 'Chocolates', 'Coffee'})
# frozenset({'Chocolates', 'Coffee', 'Juice'})
# frozenset({'Coke', 'Chocolates', 'Juice'})
# frozenset({'Tea', 'Coke', 'Chocolates'})
# frozenset({'Chocolates', 'Cookies', 'Juice'})
# frozenset({'Hot chocolate', 'Chocolates', 'Juice'})
# frozenset({'Tea', 'Chocolates', 'Juice'})
# frozenset({'Coke', 'Mineral water', 'Coffee'})
# frozenset({'Coke', 'Coffee', 'Truffles'})
# frozenset({'Cookies', 'Crisps', 'Coffee'})
# frozenset({'Cookies', 'Duck egg', 'Coffee'})
# frozenset({'Cookies', 'Coffee', 'My-5 Fruit Shoot'})
# frozenset({'Crisps', 'Coffee', 'Frittata'})
# frozenset({'Hot chocolate', 'Crisps', 'Coffee'})
# frozenset({'Crisps', 'Coffee', 'Juice'})
# frozenset({'Sandwich', 'Crisps', 'Coffee'})
# frozenset({'Truffles', 'Crisps', 'Coffee'})
# frozenset({'Drinking chocolate spoons ', 'Coffee', 'Juice'})
# frozenset({'Drinking chocolate spoons ', 'Mineral water', 'Coffee'})
# frozenset({'Drinking chocolate spoons ', 'Sandwich', 'Coffee'})
# frozenset({'Duck egg', 'Coffee', 'Spanish Brunch'})
# frozenset({"Ella's Kitchen Pouches", 'Coffee', 'Juice'})
# frozenset({"Ella's Kitchen Pouches", 'Medialuna', 'Coffee'})
# frozenset({'Extra Salami or Feta', 'Coffee', 'Juice'})
# frozenset({'Salad', 'Extra Salami or Feta', 'Coffee'})
# frozenset({'Extra Salami or Feta', 'Spanish Brunch', 'Coffee'})
# frozenset({'Extra Salami or Feta', 'Toast', 'Coffee'})
# frozenset({'Focaccia', 'Coffee', 'Hearty & Seasonal'})
# frozenset({'Focaccia', 'Coffee', 'Medialuna'})
# frozenset({'Mineral water', 'Coffee', 'Frittata'})
# frozenset({'Smoothies', 'Coffee', 'Frittata'})
# frozenset({'Fudge', 'Jam', 'Coffee'})
# frozenset({'Granola', 'Toast', 'Coffee'})
# frozenset({'Half slice Monster ', 'Coffee', 'Juice'})
# frozenset({'Mighty Protein', 'Coffee', 'Hearty & Seasonal'})
# frozenset({'Mineral water', 'Coffee', 'Hearty & Seasonal'})
# frozenset({'Pick and Mix Bowls', 'Coffee', 'Hearty & Seasonal'})
# frozenset({'Smoothies', 'Coffee', 'Hearty & Seasonal'})
# frozenset({'Tea', 'Honey', 'Coffee'})
# frozenset({'Keeping It Local', 'Jam', 'Coffee'})
# frozenset({'Tartine', 'Jam', 'Coffee'})
# frozenset({'Jammie Dodgers', 'Coffee', 'Juice'})
# frozenset({'Jammie Dodgers', 'Tiffin', 'Coffee'})
# frozenset({'Jammie Dodgers', 'Vegan mincepie', 'Coffee'})
# frozenset({'Spanish Brunch', 'Coffee', 'Juice'})
# frozenset({'Sandwich', 'Lemon and coconut', 'Coffee'})
# frozenset({'Salad', 'Mineral water', 'Coffee'})
# frozenset({'Tartine', 'Mineral water', 'Coffee'})
# frozenset({'Vegan mincepie', 'Mineral water', 'Coffee'})
# frozenset({'Pick and Mix Bowls', 'Tartine', 'Coffee'})
# frozenset({'Salad', 'Spanish Brunch', 'Coffee'})
# frozenset({'Salad', 'Truffles', 'Coffee'})
# frozenset({'Smoothies', 'Coffee', 'Spanish Brunch'})
# frozenset({'Spanish Brunch', 'The Nomad', 'Coffee'})
# frozenset({'Spanish Brunch', 'Coffee', 'Truffles'})
# frozenset({'Coke', 'Cookies', 'Juice'})
# frozenset({'Coke', 'Crisps', 'Sandwich'})
# frozenset({'Coke', 'Sandwich', 'Frittata'})
# frozenset({'Coke', 'Medialuna', 'Juice'})
# frozenset({'Coke', 'Mineral water', 'Juice'})
# frozenset({'Coke', 'Pastry', 'Juice'})
# frozenset({'Coke', 'Sandwich', 'Juice'})
# frozenset({'Tiffin', 'Coke', 'Juice'})
# frozenset({'Coke', 'Truffles', 'Juice'})
# frozenset({'Coke', 'Medialuna', 'Sandwich'})
# frozenset({'Coke', 'Mineral water', 'Sandwich'})
# frozenset({'Coke', 'Mineral water', 'Soup'})
# frozenset({'Tea', 'Coke', 'Mineral water'})
# frozenset({'Coke', 'Sandwich', 'Muffin'})
# frozenset({'Coke', 'Pastry', 'Truffles'})
# frozenset({'Salad', 'Coke', 'Truffles'})
# frozenset({'Coke', 'Sandwich', 'Smoothies'})
# frozenset({'Coke', 'Sandwich', 'Soup'})
# frozenset({'Tiffin', 'Coke', 'Sandwich'})
# frozenset({'Coke', 'Sandwich', 'Truffles'})
# frozenset({'Scone', 'Coke', 'Toast'})
# frozenset({'Coke', 'Tea', 'Spanish Brunch'})
# frozenset({'Tiffin', 'Coke', 'Tea'})
# frozenset({"Ella's Kitchen Pouches", 'Cookies', 'Juice'})
# frozenset({"Ella's Kitchen Pouches", 'Tea', 'Cookies'})
# frozenset({'Hot chocolate', 'Cookies', 'Hearty & Seasonal'})
# frozenset({'Hot chocolate', 'Mineral water', 'Cookies'})
# frozenset({'Hot chocolate', 'Cookies', 'Scandinavian'})
# frozenset({'Hot chocolate', 'Scone', 'Cookies'})
# frozenset({'Hot chocolate', 'Smoothies', 'Cookies'})
# frozenset({'Muffin', 'Cookies', 'Juice'})
# frozenset({'Pick and Mix Bowls', 'Cookies', 'Juice'})
# frozenset({'Sandwich', 'Cookies', 'Juice'})
# frozenset({'Scone', 'Mineral water', 'Cookies'})
# frozenset({'Salad', 'Scone', 'Cookies'})
# frozenset({'Salad', 'Soup', 'Cookies'})
# frozenset({'Salad', 'Truffles', 'Cookies'})
# frozenset({'Scone', 'Soup', 'Cookies'})
# frozenset({'Soup', 'Cookies', 'Truffles'})
# frozenset({'Spanish Brunch', 'The Nomad', 'Cookies'})
# frozenset({'Tiffin', 'Toast', 'Cookies'})
# frozenset({'Crisps', 'Juice', 'Frittata'})
# frozenset({'Crisps', 'Medialuna', 'Juice'})
# frozenset({'Crisps', 'Truffles', 'Juice'})
# frozenset({'Duck egg', 'Tea', 'Spanish Brunch'})
# frozenset({'Jam', "Ella's Kitchen Pouches", 'Juice'})
# frozenset({'Tea', "Ella's Kitchen Pouches", 'Juice'})
# frozenset({'Tea', 'Medialuna', "Ella's Kitchen Pouches"})
# frozenset({'Salad', 'Extra Salami or Feta', 'Juice'})
# frozenset({'Extra Salami or Feta', 'Spanish Brunch', 'Juice'})
# frozenset({'Salad', 'Extra Salami or Feta', 'Sandwich'})
# frozenset({'Salad', 'Extra Salami or Feta', 'Scandinavian'})
# frozenset({'Salad', 'Extra Salami or Feta', 'Spanish Brunch'})
# frozenset({'Salad', 'Extra Salami or Feta', 'Tea'})
# frozenset({'Salad', 'Extra Salami or Feta', 'Toast'})
# frozenset({'Extra Salami or Feta', 'Spanish Brunch', 'Truffles'})
# frozenset({'Tea', 'Farm House', 'Hearty & Seasonal'})
# frozenset({'Pastry', 'Farm House', 'Medialuna'})
# frozenset({'Pastry', 'Farm House', 'Scandinavian'})
# frozenset({'Salad', 'Spanish Brunch', 'Farm House'})
# frozenset({'Toast', 'Farm House', 'Scandinavian'})
# frozenset({'Soup', 'Tea', 'Focaccia'})
# frozenset({'Scone', 'Juice', 'Frittata'})
# frozenset({'Fudge', 'Jam', 'Juice'})
# frozenset({'Fudge', 'Tea', 'Jam'})
# frozenset({'Fudge', 'Spanish Brunch', 'Tea'})
# frozenset({'Hot chocolate', 'Granola', 'Sandwich'})
# frozenset({'Hot chocolate', 'Granola', 'Tea'})
# frozenset({'Granola', 'Tea', 'Sandwich'})
# frozenset({'Granola', 'Tea', 'Spanish Brunch'})
# frozenset({'Sandwich', 'Mineral water', 'Hearty & Seasonal'})
# frozenset({'Smoothies', 'Soup', 'Hearty & Seasonal'})
# frozenset({'Hot chocolate', 'Medialuna', 'Jammie Dodgers'})
# frozenset({'Hot chocolate', 'Vegan mincepie', 'Jammie Dodgers'})
# frozenset({'Hot chocolate', 'Toast', 'Juice'})
# frozenset({'Hot chocolate', 'Truffles', 'Juice'})
# frozenset({'Hot chocolate', 'Medialuna', 'Toast'})
# frozenset({'Hot chocolate', 'Smoothies', 'Muffin'})
# frozenset({'Hot chocolate', 'Toast', 'Muffin'})
# frozenset({'Hot chocolate', 'Pastry', 'Tiffin'})
# frozenset({'Hot chocolate', 'Tea', 'Salad'})
# frozenset({'Hot chocolate', 'Sandwich', 'Toast'})
# frozenset({'Hot chocolate', 'Scone', 'Soup'})
# frozenset({'Spanish Brunch', 'Tea', 'Jam'})
# frozenset({'Jammie Dodgers', 'Muffin', 'Juice'})
# frozenset({'Jammie Dodgers', 'Tiffin', 'Juice'})
# frozenset({'Jammie Dodgers', 'Medialuna', 'Muffin'})
# frozenset({'Jammie Dodgers', 'Sandwich', 'Muffin'})
# frozenset({'Jammie Dodgers', 'Tea', 'Muffin'})
# frozenset({'Jammie Dodgers', 'Sandwich', 'Tiffin'})
# frozenset({'Jammie Dodgers', 'Smoothies', 'Tea'})
# frozenset({'Jammie Dodgers', 'Tiffin', 'Tea'})
# frozenset({'Medialuna', 'Truffles', 'Juice'})
# frozenset({'Pick and Mix Bowls', 'Mineral water', 'Juice'})
# frozenset({'Salad', 'Mineral water', 'Juice'})
# frozenset({'Sandwich', 'Mineral water', 'Juice'})
# frozenset({'Soup', 'Mineral water', 'Juice'})
# frozenset({'Mineral water', 'Truffles', 'Juice'})
# frozenset({'Smoothies', 'Muffin', 'Juice'})
# frozenset({'Salad', 'Sandwich', 'Juice'})
# frozenset({'Salad', 'Spanish Brunch', 'Juice'})
# frozenset({'Sandwich', 'Spanish Brunch', 'Juice'})
# frozenset({'Sandwich', 'Toast', 'Juice'})
# frozenset({'Scone', 'Toast', 'Juice'})
# frozenset({'Scone', 'Truffles', 'Juice'})
# frozenset({'Spanish Brunch', 'The Nomad', 'Juice'})
# frozenset({'Spanish Brunch', 'Toast', 'Juice'})
# frozenset({'Spanish Brunch', 'Truffles', 'Juice'})
# frozenset({'Vegan mincepie', 'Tea', 'Juice'})
# frozenset({'Sandwich', 'Medialuna', 'Soup'})
# frozenset({'Tiffin', 'Sandwich', 'Medialuna'})
# frozenset({'Tea', 'Vegan mincepie', 'Medialuna'})
# frozenset({'Salad', 'Soup', 'Mineral water'})
# frozenset({'Sandwich', 'Mineral water', 'Soup'})
# frozenset({'Sandwich', 'Mineral water', 'Truffles'})
# frozenset({'Scone', 'Mineral water', 'Truffles'})
# frozenset({'Tea', 'Soup', 'Mineral water'})
# frozenset({'Soup', 'Mineral water', 'Truffles'})
# frozenset({'Tea', 'Spanish Brunch', 'Mineral water'})
# frozenset({'Spanish Brunch', 'Mineral water', 'Truffles'})
# frozenset({'The Nomad', 'Truffles', 'Muffin'})
# frozenset({'Pastry', 'Sandwich', 'Truffles'})
# frozenset({'Tiffin', 'Pastry', 'Tea'})
# frozenset({'Salad', 'Sandwich', 'Truffles'})
# frozenset({'Salad', 'Smoothies', 'Soup'})
# frozenset({'Salad', 'Soup', 'Spanish Brunch'})
# frozenset({'Salad', 'Soup', 'Tea'})
# frozenset({'Salad', 'Soup', 'Truffles'})
# frozenset({'Salad', 'Spanish Brunch', 'Tea'})
# frozenset({'Salad', 'Spanish Brunch', 'Toast'})
# frozenset({'Salad', 'Tea', 'Truffles'})
# frozenset({'Sandwich', 'Smoothies', 'Soup'})
# frozenset({'Sandwich', 'Toast', 'Spanish Brunch'})
# frozenset({'Sandwich', 'Truffles', 'Spanish Brunch'})
# frozenset({'Tiffin', 'Scone', 'Tea'})
# frozenset({'Smoothies', 'Tea', 'Spanish Brunch'})
# frozenset({'Spanish Brunch', 'Tea', 'The Nomad'})
# frozenset({'Bakewell', 'Bread', 'Tea', 'Alfajores'})
# frozenset({'Hot chocolate', 'Bread', 'Brownie', 'Alfajores'})
# frozenset({'Tea', 'Bread', 'Brownie', 'Alfajores'})
# frozenset({'Juice', 'Bread', 'Cookies', 'Alfajores'})
# frozenset({'Bread', 'Sandwich', 'Cookies', 'Alfajores'})
# frozenset({'Fudge', 'Bread', 'Medialuna', 'Alfajores'})
# frozenset({'Fudge', 'Bread', 'Sandwich', 'Alfajores'})
# frozenset({'Hot chocolate', 'Bread', 'Medialuna', 'Alfajores'})
# frozenset({'Hot chocolate', 'Bread', 'Tea', 'Alfajores'})
# frozenset({'Bread', 'Medialuna', 'Jam', 'Alfajores'})
# frozenset({'Bread', 'Tea', 'Jam', 'Alfajores'})
# frozenset({'Juice', 'Brownie', 'Coffee', 'Alfajores'})
# frozenset({'Juice', 'Brownie', 'Cookies', 'Alfajores'})
# frozenset({'Hot chocolate', 'Brownie', 'Tea', 'Alfajores'})
# frozenset({'Tea', 'Pastry', 'Brownie', 'Alfajores'})
# frozenset({'Mineral water', 'Coffee', 'Cake', 'Alfajores'})
# frozenset({'Spanish Brunch', 'Tea', 'Cake', 'Alfajores'})
# frozenset({'Juice', 'Coke', 'Coffee', 'Alfajores'})
# frozenset({'Sandwich', 'Coke', 'Coffee', 'Alfajores'})
# frozenset({'Cookies', 'Coffee', 'Alfajores', 'Hot chocolate'})
# frozenset({'Cookies', 'Juice', 'Coffee', 'Alfajores'})
# frozenset({'Cookies', 'Mineral water', 'Coffee', 'Alfajores'})
# frozenset({'Cookies', 'Sandwich', 'Coffee', 'Alfajores'})
# frozenset({'Hot chocolate', 'Mineral water', 'Coffee', 'Alfajores'})
# frozenset({'Hot chocolate', 'Muffin', 'Coffee', 'Alfajores'})
# frozenset({'Hot chocolate', 'Tea', 'Coffee', 'Alfajores'})
# frozenset({'Hot chocolate', 'Tiffin', 'Coffee', 'Alfajores'})
# frozenset({'Hot chocolate', 'Toast', 'Coffee', 'Alfajores'})
# frozenset({'Juice', 'Medialuna', 'Coffee', 'Alfajores'})
# frozenset({'Juice', 'Toast', 'Coffee', 'Alfajores'})
# frozenset({'Juice', 'Truffles', 'Coffee', 'Alfajores'})
# frozenset({'Sandwich', 'Mineral water', 'Coffee', 'Alfajores'})
# frozenset({'Tea', 'Mineral water', 'Coffee', 'Alfajores'})
# frozenset({'Tiffin', 'Pastry', 'Coffee', 'Alfajores'})
# frozenset({'Salad', 'Sandwich', 'Coffee', 'Alfajores'})
# frozenset({'Truffles', 'Sandwich', 'Coffee', 'Alfajores'})
# frozenset({'Toast', 'Tea', 'Coffee', 'Alfajores'})
# frozenset({'Tea', 'Coke', 'Pastry', 'Alfajores'})
# frozenset({'Hot chocolate', 'Sandwich', 'Cookies', 'Alfajores'})
# frozenset({'Juice', 'Mineral water', 'Cookies', 'Alfajores'})
# frozenset({'Juice', 'Sandwich', 'Cookies', 'Alfajores'})
# frozenset({'Juice', 'Tea', 'Cookies', 'Alfajores'})
# frozenset({'Tea', 'Mineral water', 'Cookies', 'Alfajores'})
# frozenset({'Hot chocolate', 'Tea', 'Juice', 'Alfajores'})
# frozenset({'Hot chocolate', 'Sandwich', 'Tea', 'Alfajores'})
# frozenset({'Tea', 'Medialuna', 'Jam', 'Alfajores'})
# frozenset({'Sandwich', 'Tea', 'Juice', 'Alfajores'})
# frozenset({'Spanish Brunch', 'Tea', 'Juice', 'Alfajores'})
# frozenset({'Tiffin', 'Pastry', 'Tea', 'Alfajores'})
# frozenset({'Sandwich', 'Tea', 'Spanish Brunch', 'Alfajores'})
# frozenset({'Juice', 'Muffin', 'Coffee', 'Art Tray'})
# frozenset({'Bakewell', 'Bread', 'Brownie', 'Coffee'})
# frozenset({'Bakewell', 'Coffee', 'Cake', 'Cookies'})
# frozenset({'Bakewell', 'Coffee', 'Cake', 'Tea'})
# frozenset({'Bakewell', 'Sandwich', 'Coffee', 'Cookies'})
# frozenset({'Bakewell', 'Tea', 'Coffee', 'Juice'})
# frozenset({'Bread', 'Spanish Brunch', 'Brownie', 'Cake'})
# frozenset({'Toast', 'Bread', 'Brownie', 'Cake'})
# frozenset({'Tea', 'Bread', 'Brownie', 'Chicken Stew'})
# frozenset({'Jammie Dodgers', 'Bread', 'Brownie', 'Tea'})
# frozenset({'Bread', 'Brownie', 'Scone', 'Juice'})
# frozenset({'Tea', 'Bread', 'Brownie', 'Toast'})
# frozenset({'Bread', 'Soup', 'Cake', 'Chicken Stew'})
# frozenset({'Bread', 'Coffee', 'Extra Salami or Feta', 'Cake'})
# frozenset({'Bread', 'Smoothies', 'Coffee', 'Cake'})
# frozenset({'Juice', 'Bread', 'Cake', 'Eggs'})
# frozenset({'Salad', 'Bread', 'Extra Salami or Feta', 'Cake'})
# frozenset({'Hot chocolate', 'Bread', 'Cake', 'Jammie Dodgers'})
# frozenset({'Hot chocolate', 'Bread', 'Cake', 'Scone'})
# frozenset({'Jammie Dodgers', 'Bread', 'Cake', 'Juice'})
# frozenset({'Jammie Dodgers', 'Bread', 'Cake', 'Muffin'})
# frozenset({'Jammie Dodgers', 'Bread', 'Spanish Brunch', 'Cake'})
# frozenset({'Jammie Dodgers', 'Bread', 'Tea', 'Cake'})
# frozenset({'Jammie Dodgers', 'Bread', 'Truffles', 'Cake'})
# frozenset({'Bread', 'Medialuna', 'Cake', 'Muffin'})
# frozenset({'Bread', 'Sandwich', 'Cake', 'Smoothies'})
# frozenset({'Bread', 'Sandwich', 'Cake', 'Soup'})
# frozenset({'Toast', 'Bread', 'Tea', 'Cake'})
# frozenset({'Bread', 'Coke', 'Coffee', 'Chicken Stew'})
# frozenset({'Bread', 'Soup', 'Coffee', 'Chicken Stew'})
# frozenset({'Tiffin', 'Bread', 'Coffee', 'Chicken Stew'})
# frozenset({'Bread', 'Truffles', 'Coffee', 'Chicken Stew'})
# frozenset({'Bread', 'Sandwich', 'Tea', 'Chicken Stew'})
# frozenset({'Bread', 'Soup', 'Tea', 'Chicken Stew'})
# frozenset({'Tiffin', 'Bread', 'Tea', 'Chicken Stew'})
# frozenset({'Bread', 'Coke', 'Mineral water', 'Coffee'})
# frozenset({'Bread', 'Coke', 'Sandwich', 'Coffee'})
# frozenset({'Bread', 'Coke', 'Coffee', 'Soup'})
# frozenset({'Cookies', 'Bread', 'Coffee', 'Frittata'})
# frozenset({'Bread', 'Crisps', 'Coffee', 'Juice'})
# frozenset({'Bread', 'Truffles', 'Crisps', 'Coffee'})
# frozenset({'Salad', 'Bread', 'Extra Salami or Feta', 'Coffee'})
# frozenset({'Bread', 'Sandwich', 'Extra Salami or Feta', 'Coffee'})
# frozenset({'Bread', 'Sandwich', 'Farm House', 'Coffee'})
# frozenset({'Bread', 'Focaccia', 'Coffee', 'Medialuna'})
# frozenset({'Juice', 'Bread', 'Coffee', 'Frittata'})
# frozenset({'Scone', 'Bread', 'Coffee', 'Frittata'})
# frozenset({'Scandinavian', 'Bread', 'Coffee', 'Fudge'})
# frozenset({'Bread', 'Granola', 'Pastry', 'Coffee'})
# frozenset({'Hot chocolate', 'Bread', 'Coffee', 'Scandinavian'})
# frozenset({'Hot chocolate', 'Bread', 'Vegan mincepie', 'Coffee'})
# frozenset({'Bread', 'Medialuna', 'Jam', 'Coffee'})
# frozenset({'Jammie Dodgers', 'Bread', 'Coffee', 'Juice'})
# frozenset({'Jammie Dodgers', 'Bread', 'Coffee', 'Muffin'})
# frozenset({'Jammie Dodgers', 'Bread', 'Tea', 'Coffee'})
# frozenset({'Jammie Dodgers', 'Bread', 'Tiffin', 'Coffee'})
# frozenset({'Bread', 'Spanish Brunch', 'Coffee', 'Juice'})
# frozenset({'Bread', 'Truffles', 'Coffee', 'Juice'})
# frozenset({'Bread', 'Soup', 'Mineral water', 'Coffee'})
# frozenset({'Bread', 'Pastry', 'Coffee', 'Spanish Brunch'})
# frozenset({'Salad', 'Bread', 'Spanish Brunch', 'Coffee'})
# frozenset({'Bread', 'Sandwich', 'Coffee', 'Smoothies'})
# frozenset({'Bread', 'Sandwich', 'The Nomad', 'Coffee'})
# frozenset({'Bread', 'Smoothies', 'Coffee', 'Spanish Brunch'})
# frozenset({'Tiffin', 'Bread', 'Tea', 'Coffee'})
# frozenset({'Bread', 'Coke', 'Sandwich', 'Soup'})
# frozenset({'Bread', 'Coke', 'Tea', 'Sandwich'})
# frozenset({'Hot chocolate', 'Bread', 'Cookies', 'Hearty & Seasonal'})
# frozenset({'Hot chocolate', 'Bread', 'Cookies', 'Scone'})
# frozenset({'Bread', 'Tea', 'Jam', 'Cookies'})
# frozenset({'Bread', 'Sandwich', 'Cookies', 'Juice'})
# frozenset({'Salad', 'Bread', 'Soup', 'Cookies'})
# frozenset({'Salad', 'Bread', 'Truffles', 'Cookies'})
# frozenset({'Scone', 'Bread', 'Soup', 'Cookies'})
# frozenset({'Bread', 'Soup', 'Cookies', 'Truffles'})
# frozenset({'Tiffin', 'Bread', 'Toast', 'Cookies'})
# frozenset({'Bread', 'Crisps', 'Truffles', 'Juice'})
# frozenset({'Salad', 'Bread', 'Extra Salami or Feta', 'Scandinavian'})
# frozenset({'Bread', 'Pastry', 'Farm House', 'Medialuna'})
# frozenset({'Hot chocolate', 'Bread', 'Tea', 'Jammie Dodgers'})
# frozenset({'Hot chocolate', 'Bread', 'Medialuna', 'Toast'})
# frozenset({'Hot chocolate', 'Bread', 'Pastry', 'Muffin'})
# frozenset({'Hot chocolate', 'Bread', 'Tiffin', 'Tea'})
# frozenset({'Tea', 'Bread', 'Medialuna', 'Jam'})
# frozenset({'Jammie Dodgers', 'Bread', 'Tiffin', 'Tea'})
# frozenset({'Bread', 'Pastry', 'Scone', 'Juice'})
# frozenset({'Bread', 'Sandwich', 'Medialuna', 'Muffin'})
# frozenset({'Tea', 'Bread', 'Sandwich', 'Medialuna'})
# frozenset({'Tiffin', 'Bread', 'Sandwich', 'Medialuna'})
# frozenset({'Bread', 'Truffles', 'Mineral water', 'Scone'})
# frozenset({'Bread', 'Soup', 'Tea', 'Muffin'})
# frozenset({'Salad', 'Bread', 'Soup', 'Truffles'})
# frozenset({'Hot chocolate', 'Brownie', 'Cake', 'Tea'})
# frozenset({'Tea', 'Brownie', 'Toast', 'Cake'})
# frozenset({'Brownie', 'Farm House', 'Coffee', 'Juice'})
# frozenset({'Tea', 'Brownie', 'Farm House', 'Coffee'})
# frozenset({'Brownie', 'Coffee', 'Juice', 'Medialuna'})
# frozenset({'Pastry', 'Brownie', 'Coffee', 'Juice'})
# frozenset({'Scone', 'Brownie', 'Coffee', 'Juice'})
# frozenset({'Tea', 'Brownie', 'Toast', 'Coffee'})
# frozenset({'Salad', 'Coffee', 'Cake', 'Chicken Stew'})
# frozenset({'Truffles', 'Coffee', 'Cake', 'Chicken Stew'})
# frozenset({'Salad', 'Truffles', 'Cake', 'Chicken Stew'})
# frozenset({'Truffles', 'Sandwich', 'Cake', 'Chicken Stew'})
# frozenset({'Soup', 'Tea', 'Cake', 'Chicken Stew'})
# frozenset({'Coke', 'Coffee', 'Cake', 'Juice'})
# frozenset({'Cookies', 'Soup', 'Coffee', 'Cake'})
# frozenset({'Cookies', 'Spanish Brunch', 'Coffee', 'Cake'})
# frozenset({'Hot chocolate', 'Extra Salami or Feta', 'Coffee', 'Cake'})
# frozenset({'Salad', 'Extra Salami or Feta', 'Coffee', 'Cake'})
# frozenset({'Toast', 'Extra Salami or Feta', 'Coffee', 'Cake'})
# frozenset({'Coffee', 'Farm House', 'Cake', 'Medialuna'})
# frozenset({'Sandwich', 'Granola', 'Coffee', 'Cake'})
# frozenset({'Sandwich', 'Coffee', 'Cake', 'Hearty & Seasonal'})
# frozenset({'Tea', 'Coffee', 'Cake', 'Hearty & Seasonal'})
# frozenset({'Hot chocolate', 'Mineral water', 'Coffee', 'Cake'})
# frozenset({'Hot chocolate', 'Soup', 'Coffee', 'Cake'})
# frozenset({'Hot chocolate', 'Coffee', 'Toast', 'Cake'})
# frozenset({'Hot chocolate', 'Vegan mincepie', 'Coffee', 'Cake'})
# frozenset({'Salad', 'Coffee', 'Cake', 'Juice'})
# frozenset({'Scone', 'Coffee', 'Cake', 'Juice'})
# frozenset({'Soup', 'Coffee', 'Cake', 'Medialuna'})
# frozenset({'Spanish Brunch', 'Coffee', 'Cake', 'Medialuna'})
# frozenset({'Mineral water', 'Sandwich', 'Coffee', 'Cake'})
# frozenset({'Pastry', 'Coffee', 'Cake', 'Spanish Brunch'})
# frozenset({'Pastry', 'Coffee', 'Cake', 'Truffles'})
# frozenset({'Salad', 'Sandwich', 'Coffee', 'Cake'})
# frozenset({'Salad', 'Spanish Brunch', 'Coffee', 'Cake'})
# frozenset({'Salad', 'Coffee', 'Cake', 'Tea'})
# frozenset({'Salad', 'Truffles', 'Coffee', 'Cake'})
# frozenset({'Sandwich', 'Coffee', 'Cake', 'Smoothies'})
# frozenset({'Sandwich', 'Coffee', 'Cake', 'Soup'})
# frozenset({'Sandwich', 'Coffee', 'Cake', 'Truffles'})
# frozenset({'Tea', 'Coffee', 'Cake', 'Scandinavian'})
# frozenset({'Tea', 'Smoothies', 'Coffee', 'Cake'})
# frozenset({'Spanish Brunch', 'Coffee', 'Cake', 'Truffles'})
# frozenset({'Sandwich', 'Coke', 'Cake', 'Juice'})
# frozenset({'Cookies', 'Sandwich', 'Cake', 'Soup'})
# frozenset({'Cookies', 'Sandwich', 'Tea', 'Cake'})
# frozenset({'Cookies', 'Soup', 'Tea', 'Cake'})
# frozenset({'Tea', 'Farm House', 'Cake', 'Medialuna'})
# frozenset({'Hot chocolate', 'Medialuna', 'Cake', 'Tea'})
# frozenset({'Hot chocolate', 'Tea', 'Cake', 'Muffin'})
# frozenset({'Hot chocolate', 'Pastry', 'Tea', 'Cake'})
# frozenset({'Hot chocolate', 'Tea', 'Salad', 'Cake'})
# frozenset({'Hot chocolate', 'Sandwich', 'Toast', 'Cake'})
# frozenset({'Tea', 'Muffin', 'Cake', 'Juice'})
# frozenset({'Scone', 'Toast', 'Cake', 'Juice'})
# frozenset({'Tea', 'Scone', 'Medialuna', 'Cake'})
# frozenset({'Scone', 'Tea', 'Cake', 'Muffin'})
# frozenset({'Sandwich', 'Soup', 'Cake', 'Smoothies'})
# frozenset({'Sandwich', 'Tea', 'Cake', 'Soup'})
# frozenset({'Scone', 'Soup', 'Tea', 'Cake'})
# frozenset({'Juice', 'Coke', 'Coffee', 'Chicken Stew'})
# frozenset({'Sandwich', 'Coke', 'Coffee', 'Chicken Stew'})
# frozenset({'Truffles', 'Coke', 'Coffee', 'Chicken Stew'})
# frozenset({'Juice', 'Sandwich', 'Coffee', 'Chicken Stew'})
# frozenset({'Juice', 'Spanish Brunch', 'Coffee', 'Chicken Stew'})
# frozenset({'Salad', 'Truffles', 'Coffee', 'Chicken Stew'})
# frozenset({'Sandwich', 'Soup', 'Coffee', 'Chicken Stew'})
# frozenset({'Truffles', 'Sandwich', 'Coffee', 'Chicken Stew'})
# frozenset({'Soup', 'Tea', 'Coffee', 'Chicken Stew'})
# frozenset({'Tiffin', 'Tea', 'Coffee', 'Chicken Stew'})
# frozenset({'Sandwich', 'Coke', 'Juice', 'Chicken Stew'})
# frozenset({'Truffles', 'Coke', 'Sandwich', 'Chicken Stew'})
# frozenset({'Cookies', 'Chocolates', 'Coffee', 'Juice'})
# frozenset({'Hot chocolate', 'Chocolates', 'Coffee', 'Juice'})
# frozenset({'Tea', 'Coke', 'Chocolates', 'Juice'})
# frozenset({'Cookies', 'Coke', 'Coffee', 'Juice'})
# frozenset({'Coke', 'Medialuna', 'Coffee', 'Juice'})
# frozenset({'Coke', 'Pastry', 'Coffee', 'Juice'})
# frozenset({'Sandwich', 'Coke', 'Coffee', 'Juice'})
# frozenset({'Truffles', 'Coke', 'Coffee', 'Juice'})
# frozenset({'Coke', 'Mineral water', 'Coffee', 'Soup'})
# frozenset({'Coke', 'Pastry', 'Coffee', 'Truffles'})
# frozenset({'Sandwich', 'Coke', 'Coffee', 'Smoothies'})
# frozenset({'Sandwich', 'Coke', 'Coffee', 'Soup'})
# frozenset({'Sandwich', 'Coke', 'Coffee', 'Truffles'})
# frozenset({'Scone', 'Coke', 'Toast', 'Coffee'})
# frozenset({'Coke', 'Tea', 'Coffee', 'Spanish Brunch'})
# frozenset({'Tiffin', 'Coke', 'Tea', 'Coffee'})
# frozenset({'Cookies', 'Hot chocolate', 'Coffee', 'Hearty & Seasonal'})
# frozenset({'Cookies', 'Sandwich', 'Coffee', 'Hot chocolate'})
# frozenset({'Cookies', 'Coffee', 'Scandinavian', 'Hot chocolate'})
# frozenset({'Cookies', 'Scone', 'Coffee', 'Hot chocolate'})
# frozenset({'Cookies', 'Pastry', 'Coffee', 'Juice'})
# frozenset({'Cookies', 'Sandwich', 'Coffee', 'Juice'})
# frozenset({'Cookies', 'Scone', 'Coffee', 'Juice'})
# frozenset({'Cookies', 'Mineral water', 'Coffee', 'Tea'})
# frozenset({'Cookies', 'Sandwich', 'Coffee', 'Soup'})
# frozenset({'Cookies', 'Scone', 'Soup', 'Coffee'})
# frozenset({'Cookies', 'Tiffin', 'Tea', 'Coffee'})
# frozenset({'Juice', 'Crisps', 'Coffee', 'Frittata'})
# frozenset({'Crisps', 'Coffee', 'Juice', 'Medialuna'})
# frozenset({'Truffles', 'Crisps', 'Coffee', 'Juice'})
# frozenset({'Salad', 'Extra Salami or Feta', 'Coffee', 'Juice'})
# frozenset({'Extra Salami or Feta', 'Spanish Brunch', 'Coffee', 'Juice'})
# frozenset({'Salad', 'Extra Salami or Feta', 'Sandwich', 'Coffee'})
# frozenset({'Salad', 'Extra Salami or Feta', 'Spanish Brunch', 'Coffee'})
# frozenset({'Salad', 'Extra Salami or Feta', 'Toast', 'Coffee'})
# frozenset({'Hot chocolate', 'Farm House', 'Coffee', 'Medialuna'})
# frozenset({'Hot chocolate', 'Pastry', 'Farm House', 'Coffee'})
# frozenset({'Pastry', 'Farm House', 'Coffee', 'Medialuna'})
# frozenset({'Tea', 'Farm House', 'Coffee', 'Medialuna'})
# frozenset({'Salad', 'Spanish Brunch', 'Farm House', 'Coffee'})
# frozenset({'Toast', 'Farm House', 'Coffee', 'Scandinavian'})
# frozenset({'Tea', 'Farm House', 'Toast', 'Coffee'})
# frozenset({'Hot chocolate', 'Vegan mincepie', 'Coffee', 'Jammie Dodgers'})
# frozenset({'Hot chocolate', 'Truffles', 'Coffee', 'Juice'})
# frozenset({'Hot chocolate', 'Sandwich', 'Toast', 'Coffee'})
# frozenset({'Hot chocolate', 'Tiffin', 'Tea', 'Coffee'})
# frozenset({'Pastry', 'Tea', 'Jam', 'Coffee'})
# frozenset({'Jammie Dodgers', 'Muffin', 'Coffee', 'Juice'})
# frozenset({'Jammie Dodgers', 'Tea', 'Coffee', 'Juice'})
# frozenset({'Jammie Dodgers', 'Tiffin', 'Coffee', 'Juice'})
# frozenset({'Jammie Dodgers', 'Tea', 'Coffee', 'Muffin'})
# frozenset({'Jammie Dodgers', 'Sandwich', 'Tiffin', 'Coffee'})
# frozenset({'Jammie Dodgers', 'Tiffin', 'Tea', 'Coffee'})
# frozenset({'Truffles', 'Medialuna', 'Coffee', 'Juice'})
# frozenset({'Sandwich', 'Mineral water', 'Coffee', 'Juice'})
# frozenset({'Soup', 'Mineral water', 'Coffee', 'Juice'})
# frozenset({'Tea', 'Muffin', 'Coffee', 'Juice'})
# frozenset({'Truffles', 'Pastry', 'Coffee', 'Juice'})
# frozenset({'Salad', 'Sandwich', 'Coffee', 'Juice'})
# frozenset({'Salad', 'Spanish Brunch', 'Coffee', 'Juice'})
# frozenset({'Sandwich', 'Spanish Brunch', 'Coffee', 'Juice'})
# frozenset({'Sandwich', 'Toast', 'Coffee', 'Juice'})
# frozenset({'Truffles', 'Sandwich', 'Coffee', 'Juice'})
# frozenset({'Scone', 'Truffles', 'Coffee', 'Juice'})
# frozenset({'Spanish Brunch', 'Tea', 'Coffee', 'Juice'})
# frozenset({'Spanish Brunch', 'Toast', 'Coffee', 'Juice'})
# frozenset({'Tiffin', 'Tea', 'Coffee', 'Juice'})
# frozenset({'Sandwich', 'Medialuna', 'Coffee', 'Muffin'})
# frozenset({'Sandwich', 'Medialuna', 'Coffee', 'Soup'})
# frozenset({'Tiffin', 'Sandwich', 'Medialuna', 'Coffee'})
# frozenset({'Tea', 'Soup', 'Medialuna', 'Coffee'})
# frozenset({'Sandwich', 'Mineral water', 'Coffee', 'Soup'})
# frozenset({'Sandwich', 'Mineral water', 'Coffee', 'Truffles'})
# frozenset({'Sandwich', 'Pastry', 'Coffee', 'Truffles'})
# frozenset({'Tiffin', 'Pastry', 'Tea', 'Coffee'})
# frozenset({'Salad', 'Sandwich', 'Coffee', 'Truffles'})
# frozenset({'Salad', 'Soup', 'Coffee', 'Spanish Brunch'})
# frozenset({'Salad', 'Spanish Brunch', 'Tea', 'Coffee'})
# frozenset({'Truffles', 'Sandwich', 'Coffee', 'Soup'})
# frozenset({'Truffles', 'Sandwich', 'Coffee', 'Spanish Brunch'})
# frozenset({'Scone', 'Tea', 'Coffee', 'The Nomad'})
# frozenset({'Tiffin', 'Scone', 'Tea', 'Coffee'})
# frozenset({'Truffles', 'Coke', 'Sandwich', 'Juice'})
# frozenset({'Coke', 'Mineral water', 'Sandwich', 'Soup'})
# frozenset({'Coke', 'Tea', 'Sandwich', 'Soup'})
# frozenset({'Hot chocolate', 'Tea', 'Cookies', 'Juice'})
# frozenset({'Hot chocolate', 'Sandwich', 'Toast', 'Cookies'})
# frozenset({'Hot chocolate', 'Tea', 'Toast', 'Cookies'})
# frozenset({'Sandwich', 'Tea', 'Cookies', 'Juice'})
# frozenset({'Salad', 'Soup', 'Cookies', 'Truffles'})
# frozenset({'Sandwich', 'Tea', 'Cookies', 'Soup'})
# frozenset({'Salad', 'Extra Salami or Feta', 'Spanish Brunch', 'Juice'})
# frozenset({'Hot chocolate', 'Pastry', 'Farm House', 'Medialuna'})
# frozenset({'Hot chocolate', 'Granola', 'Tea', 'Sandwich'})
# frozenset({'Hot chocolate', 'Sandwich', 'Toast', 'Juice'})
# frozenset({'Hot chocolate', 'Tea', 'Toast', 'Juice'})
# frozenset({'Hot chocolate', 'Medialuna', 'Tea', 'Muffin'})
# frozenset({'Hot chocolate', 'Pastry', 'Tea', 'Tiffin'})
# frozenset({'Hot chocolate', 'Sandwich', 'Tea', 'Toast'})
# frozenset({'Sandwich', 'Tea', 'Spanish Brunch', 'Juice'})
# frozenset({'Tea', 'Sandwich', 'Medialuna', 'Soup'})
# frozenset({'Bread', 'Coffee', 'Brownie', 'Tea', 'Alfajores'})
# frozenset({'Bread', 'Tea', 'Hot chocolate', 'Brownie', 'Alfajores'})
# frozenset({'Bread', 'Coffee', 'Hot chocolate', 'Tea', 'Alfajores'})
# frozenset({'Bread', 'Medialuna', 'Tea', 'Jam', 'Alfajores'})
# frozenset({'Coffee', 'Cookies', 'Hot chocolate', 'Sandwich', 'Alfajores'})
# frozenset({'Alfajores', 'Coffee', 'Cookies', 'Tea', 'Juice'})
# frozenset({'Coffee', 'Cookies', 'Mineral water', 'Tea', 'Alfajores'})
# frozenset({'Coffee', 'Hot chocolate', 'Sandwich', 'Tea', 'Alfajores'})
# frozenset({'Pastry', 'Coffee', 'Tiffin', 'Tea', 'Alfajores'})
# frozenset({'Bread', 'Cake', 'Brownie', 'Toast', 'Tea'})
# frozenset({'Bread', 'Coffee', 'Cake', 'Salad', 'Extra Salami or Feta'})
# frozenset({'Bread', 'Coffee', 'Cake', 'Hot chocolate', 'Sandwich'})
# frozenset({'Bread', 'Coffee', 'Cake', 'Scone', 'Hot chocolate'})
# frozenset({'Jammie Dodgers', 'Bread', 'Coffee', 'Cake', 'Tea'})
# frozenset({'Bread', 'Coffee', 'Cake', 'Medialuna', 'Muffin'})
# frozenset({'Bread', 'Pastry', 'Coffee', 'Cake', 'Tea'})
# frozenset({'Bread', 'Coffee', 'Cake', 'Tiffin', 'Tea'})
# frozenset({'Bread', 'Coffee', 'Chicken Stew', 'Tiffin', 'Tea'})
# frozenset({'Bread', 'Coffee', 'Scone', 'Cookies', 'Hot chocolate'})
# frozenset({'Bread', 'Coffee', 'Crisps', 'Truffles', 'Juice'})
# frozenset({'Bread', 'Pastry', 'Coffee', 'Farm House', 'Medialuna'})
# frozenset({'Jammie Dodgers', 'Bread', 'Coffee', 'Tiffin', 'Tea'})
# frozenset({'Bread', 'Coffee', 'Medialuna', 'Sandwich', 'Muffin'})
# frozenset({'Bread', 'Coffee', 'Medialuna', 'Sandwich', 'Tea'})
# frozenset({'Bread', 'Coffee', 'Medialuna', 'Sandwich', 'Tiffin'})
# frozenset({'Bread', 'Soup', 'Cookies', 'Salad', 'Truffles'})
# frozenset({'Coffee', 'Cake', 'Chicken Stew', 'Salad', 'Truffles'})
# frozenset({'Coffee', 'Cake', 'Soup', 'Cookies', 'Sandwich'})
# frozenset({'Coffee', 'Cake', 'Cookies', 'Sandwich', 'Tea'})
# frozenset({'Coffee', 'Cake', 'Soup', 'Cookies', 'Tea'})
# frozenset({'Coffee', 'Cake', 'Farm House', 'Medialuna', 'Tea'})
# frozenset({'Coffee', 'Cake', 'Medialuna', 'Hot chocolate', 'Tea'})
# frozenset({'Coffee', 'Cake', 'Hot chocolate', 'Sandwich', 'Toast'})
# frozenset({'Coffee', 'Cake', 'Tea', 'Juice', 'Muffin'})
# frozenset({'Coffee', 'Cake', 'Scone', 'Medialuna', 'Tea'})
# frozenset({'Coffee', 'Cake', 'Soup', 'Sandwich', 'Tea'})
# frozenset({'Cake', 'Soup', 'Cookies', 'Sandwich', 'Tea'})
# frozenset({'Coffee', 'Chicken Stew', 'Sandwich', 'Coke', 'Juice'})
# frozenset({'Coffee', 'Chicken Stew', 'Sandwich', 'Coke', 'Truffles'})
# frozenset({'Coffee', 'Sandwich', 'Coke', 'Truffles', 'Juice'})
# frozenset({'Coffee', 'Cookies', 'Sandwich', 'Tea', 'Juice'})
# frozenset({'Coffee', 'Soup', 'Cookies', 'Sandwich', 'Tea'})
# frozenset({'Spanish Brunch', 'Coffee', 'Salad', 'Extra Salami or Feta', 'Juice'})
# frozenset({'Pastry', 'Coffee', 'Farm House', 'Medialuna', 'Hot chocolate'})
# frozenset({'Coffee', 'Cake', 'Soup', 'Cookies', 'Sandwich', 'Tea'})
